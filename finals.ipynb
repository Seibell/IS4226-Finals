# %% [markdown]
# Adding stored data to store the trades for calculation of results

# %%
# Changes from 8:
# Almost similar to notebook 8, but for multiple instruments
# The adding of dictionaries, so that the data for all stocks can be stored
# Added one more func to stop trading when total capital  < 0. Previous model doesnt takes that into account.

# %%
# Install all important libraries
# !pip install yfinance
# !pip install ta
# Out:
# Requirement already satisfied: yfinance in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.26.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.2.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.12.0)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ta in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from ta) (1.26.0)
# Requirement already satisfied: pandas in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from ta) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas->ta) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas->ta) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# NSE list Dont run
list = ["BRITANNIA.NS", "ULTRACEMCO.NS","KOTAKBANK.NS", "HEROMOTOCO.NS" , "BAJAJ-AUTO.NS", "GRASIM.NS","ONGC.NS", "TITAN.NS" , "SHREECEM.NS" ,\
        "NESTLEIND.NS", "GAIL.NS", "CIPLA.NS", "BHARTIARTL.NS" ,"NTPC.NS", "TATASTEEL.NS", "COALINDIA.NS", "BAJFINANCE.NS", "ICICIBANK.NS",\
       "BAJAJFINSV.NS", "WIPRO.NS", "HINDALCO.NS" , "HDFCLIFE.NS", "MARUTI.NS", "RELIANCE.NS", "TCS.NS", "LT.NS", "INDUSINDBK.NS", "ITC.NS" , "TECHM.NS"]

# %%
# SGX list Dont run
list = ["C52.SI", "T39.SI", "S68.SI", "G13.SI", "V03.SI" , "U11.SI", "C07.SI" , "D05.SI", "Z74.SI",\
        "D01.SI", "O39.SI", "S63.SI", "A17U.SI" , "BN4.SI","BS6.SI", "M44U.SI", "C31.SI", "H78.SI", \
        "Y92.SI", "C38U.SI", "U14.SI", "N2IU.SI" , "F34.SI" , "C09.SI" , "J36.SI", "S58.SI" , "C6L.SI", "J37.SI", "U96.SI" ,"1810.HK"]

# %%
# import all libraries

from ta.utils import dropna
from ta.volatility import BollingerBands
from ta.trend import ADXIndicator
from ta.volatility import AverageTrueRange
from ta.trend import SMAIndicator
from ta.momentum import RSIIndicator
from ta.volume import VolumeWeightedAveragePrice

import math
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# For event based backtesting, an imporatant concept is a bar.
# A bar is unit of data or information. A bar represents an event.
# Event based Backtesting will be based on new bars coming at not on full dataset.

# First we will build a commonclass,
# this will be utilised for all the common purposes like preparing data, plotting results, placing orders etc

# %%
class Common_Class():

  def __init__(self, symbol, start, end, interval, capital, transaction_cost, verbose=True):
        # Initialize variables
        self.all_data = {}
        self.position = {}
        self.quantity = {}
        for stock in symbol:
            self.quantity[stock] = 0
            self.position[stock] = 0

        self.symbol = symbol
        self.start = start
        self.end = end
        self.interval = interval
        self.initial_capital = capital
        self.capital = capital
        self.transaction_cost = transaction_cost
        self.trades = 0
        self.verbose = verbose
        self.stored_data = pd.DataFrame(columns=['trade', 'date', 'position', 'price', 'symbol', 'quantity', 'capital'])
        self.prepare_data()


  def prepare_data(self):
        for i in self.symbol:
            stock_data = yf.Ticker(i)
            hist_stock = stock_data.history(start=self.start, end=self.end, interval=self.interval)
            bt_data = pd.DataFrame()
            bt_data["Close_Price"] = hist_stock["Close"]
            bt_data["Return"] = np.log(bt_data["Close_Price"] / bt_data["Close_Price"].shift(1))
            bt_data = bt_data.dropna()
            self.all_data[i] = bt_data

  def close_graph(self, stock):
    i = str(stock)
    plt.figure(figsize=(15, 5))
    plt.plot(self.all_data[i]["Close_Price"] ,color='black', label='Price', linestyle='dashed')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.title("Close Prices of {}".format(i))
    plt.legend()
    plt.grid()
    plt.show()

  def return_date_price(self, bar, stock):
        i = str(stock)
        date = str(self.all_data[i].index[bar])[:10]
        price = self.all_data[i].Close_Price.iloc[bar]
        return date, price

  def realised_balance(self, bar):
    #Returns you the realised capital in your account at a given time period / bar
    date, price = self.return_date_price(bar, self.symbol[0]) # only concerned with date so any stock will do
    print("Date :{} | Realised Balance: {:0.1f}".format(date,self.capital))

  def unrealised_balance(self, bar):
    #Returns you the unrealised capital (trades in progress) in your account at a given time period / bar
    ub = 0
    for stock in self.symbol:
      date, price = self.return_date_price(bar, stock)
      ub =  ub + self.quantity['{}'.format(stock)] *price
    #print("Date :{} | Unrealised Balance: {:0.1f}".format(date,ub))

  def total_balance(self, bar):
        ub = 0
        for stock in self.symbol:
            date, price = self.return_date_price(bar, stock)
            ub += self.quantity[stock] * price
        tb = ub + self.capital
        return tb

  def store_results(self, trade, date, position, price, symbol, quantity, capital):
        trade_detail = pd.DataFrame({
            'trade': pd.Series(trade),
            'date': pd.Series(date),
            'position': pd.Series(position),
            'price': pd.Series(price),
            'symbol': pd.Series(symbol),
            'quantity': pd.Series(quantity),
            'capital': pd.Series(capital)
        })
        self.stored_data = pd.concat([self.stored_data, trade_detail])

  def performance_plots(self):

    Final_result_data = self.Final_result_data #saving time to write self everywhere
    interval = str(self.interval)
    f,ax = plt.subplots(2,3,figsize=(20,10))

    #plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)

    #f.tight_layout(h_pad=5, w_pad=2)

    #plot 1: Close Price os stock
    plt.subplot(2, 3, 1)
    for stock in self.symbol:
      plt.plot(Final_result_data['Returns_{}'.format(stock)].cumsum(), label='{}'.format(stock), linestyle='dashed')
    plt.title("Cum Log returns of included stocks")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 2: Histogram of dtrstegy returns
    plt.subplot(2, 3, 2)
    plt.hist(Final_result_data['capital_log_returns'], bins = 35, label='Strategy Returns', linestyle='dashed')
    plt.title("Histogram of Strategy returns")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 3: Strategy vs Instrument
    plt.subplot(2, 3, 3)
    plt.plot(Final_result_data['Total_Stock_Returns_cum_sum'],color='red', label='Equal weighted stock Returns', linestyle='dashed')
    plt.plot(Final_result_data['capital_returns_log_cum_sum'].dropna(), label ='Strategy Returns')
    plt.title("Strategy Vs Stock Cum Return Curve")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 4: Drawdown
    plt.subplot(2, 3, 4)
    plt.plot(Final_result_data["capital_returns_log_cum_sum"].dropna(), label='Cum log returns')
    plt.plot(Final_result_data["Cum_Max"].dropna(), label =  'Max Drawdown')
    plt.title("Drawdown")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 5: Equity Curve
    plt.subplot(2, 3,  5)
    plt.plot(Final_result_data["capital"].dropna(), label =  'Equity $')
    plt.title("Equity Curve")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    plt.suptitle("Performance Plots")
    f.delaxes(ax[1,2]) # to delete the last subplot

    plt.show()

  def performance(self):
        df = pd.DataFrame()
        df['capital'] = self.stored_data.groupby('date').agg({'capital': 'mean'})

        trade_start_date = df.index[0]
        trade_end_date = df.index[-1]

        for stock in self.symbol:
            A = self.all_data[stock][trade_start_date:trade_end_date]['Return'].tolist()
            df[f'Returns_{stock}'] = A

        c = df.columns
        df['Total_Stock_Returns'] = df.loc[:, c[-len(self.symbol):]].mean(axis=1)
        df['Total_Stock_Returns_cum_sum'] = df['Total_Stock_Returns'].cumsum()
        df.index = range(df.shape[0])

        df['capital_after_settlement'] = df['capital'].shift(-1)

        df['capital_regular_returns'] = df['capital_after_settlement'] / df['capital'] - 1
        df['capital_log_returns'] = np.log(df['capital_after_settlement'] / df['capital'])
        df['capital_returns_log_cum_sum'] = df['capital_log_returns'].cumsum()

        df['Cum_Max'] = df['capital_returns_log_cum_sum'].cummax()
        df['drawdown'] = df['Cum_Max'] - df['capital_returns_log_cum_sum']

        df.dropna(inplace=True)

        Final_result_data = df

        # Calculate performance metrics
        daily_log_mean_ret = Final_result_data['capital_log_returns'].mean()
        annual_log_ret = 252 * daily_log_mean_ret
        annual_regular_return = (np.exp(annual_log_ret) - 1) * 100

        daily_regular_std = (np.exp(Final_result_data['capital_log_returns']) - 1).std()
        annual_regular_std = daily_regular_std * np.sqrt(252) * 100

        SR = annual_regular_return / annual_regular_std

        returns = (self.capital - self.initial_capital) / self.initial_capital * 100

        Drawdown = Final_result_data['drawdown'].max() * 100

        zero_periods = Final_result_data[Final_result_data['drawdown'] == 0]
        delta_values = (zero_periods.index[1:] - zero_periods.index[:-1])

        only_neg_log_returns = Final_result_data[Final_result_data['capital_log_returns'] < 0]['capital_log_returns']
        only_neg_regular_returns = np.exp(only_neg_log_returns) - 1

        daily_std_dev_for_sortino = only_neg_regular_returns.std()
        annual_std_dev_for_sortino = daily_std_dev_for_sortino * np.sqrt(252) * 100

        sortino = annual_regular_return / annual_std_dev_for_sortino

        # Store metrics for hyperparameter tuning
        self.metrics = {
            'annual_return': annual_regular_return,
            'annual_std': annual_regular_std,
            'sharpe_ratio': SR,
            'sortino_ratio': sortino,
            'max_drawdown': Drawdown,
            'total_trades': self.trades,
            'returns': returns,
        }

        # Print performance metrics if verbose
        if self.verbose:
            print("=" * 50)
            print("Performance Metrics")
            print(f"The total capital at end of strategy: {self.capital:0.1f}")
            print(f"The annual regular returns: {annual_regular_return:0.2f} %")
            print(f"The annual regular std deviation: {annual_regular_std:0.2f} %")
            print(f"The annual Sharpe Ratio: {SR:0.2f}")
            print(f"The returns on investment from {self.start} to {self.end} by this strategy is {returns:0.1f} %")
            print(f"The maximum drawdown: {Drawdown:.2f} %")
            print(f"The maximum drawdown period: {delta_values.max() if not delta_values.empty else 0:.2f} days")
            print(f"The annual Sortino Ratio: {sortino:0.2f}")
            print(f"The total trades taken by the strategy: {self.trades}")
            print("=" * 50)

        self.Final_result_data = Final_result_data

  def buy_order(self,bar,stock,quantity=None, dollar =None ):
    date, price = self.return_date_price(bar,stock)
    if quantity == None:
      quantity = int(dollar/price)
    self.capital = self.capital - ((quantity * price)*(1 + self.transaction_cost)) # capital will be lost in buying
    self.quantity['{}'.format(stock)] = self.quantity['{}'.format(stock)] + quantity
    self.trades = self.trades + 1
    self.position['{}'.format(stock)] = 1
    tb = self.total_balance(bar)
    #self.quantity['{}'.format(stock)]*price + self.capital # this is just for one stock, however, I need for all the stocks
    self.store_results(self.trades, date, self.position['{}'.format(stock)], price, stock, quantity, tb)


    if self.verbose:
      print("Bought {} shares of {} at {:0.1f} per share worth {:0.1f} $".format(quantity,stock, price, quantity * price))
      print('Total quantity for {} is {}'.format(stock,self.quantity['{}'.format(stock)]))
      self.realised_balance(bar)
      #self.unrealised_balance(bar)
      #self.total_balance(bar)


  def sell_order(self,bar,stock, quantity=None, dollar=None ):
    date, price = self.return_date_price(bar, stock)
    if quantity == None:
      quantity = int(dollar/price)
    self.capital = self.capital + ((quantity * price)*(1 - self.transaction_cost)) # capital will be added after selling
    self.quantity['{}'.format(stock)] = self.quantity['{}'.format(stock)] - quantity
    self.trades = self.trades + 1
    self.position['{}'.format(stock)] = -1
    tb = self.total_balance(bar) # to store the total balance due to all the stocks at the end of the day, so that I get 1 value at the EOD
    self.store_results(self.trades, date, self.position['{}'.format(stock)], price, stock, quantity, tb)


    if self.verbose:
      print("Sold {} shares of {} at {:0.1f} per share worth {:0.1f} $".format(quantity,stock, price, quantity * price))
      print('Total quantity for {} is {}'.format(stock,self.quantity['{}'.format(stock)]))
      self.realised_balance(bar)
      #self.unrealised_balance(bar)
      #self.total_balance(bar)

  def last_trade(self, bar):# this needs to be check for all open positions of all stocks

    for stock in self.symbol:
      date, price = self.return_date_price(bar, stock)
      last_quantity = self.quantity['{}'.format(stock)]
      self.capital = self.capital + last_quantity * price
      self.quantity['{}'.format(stock)] = 0 # as no more quantity now. all will be settled
      self.trades = self.trades +1
      if self.position['{}'.format(stock)] == -1: # if closing out a short position
        last_quantity = - last_quantity # to keep a positve nymber in records. Note, self.quantity is always maintianing a +/- sign.
        self.position['{}'.format(stock)] = 1 # to record we are buying to close out
      else:
        last_quantity =  last_quantity # to keep a positve nymber in records
        self.position['{}'.format(stock)] = -1 # to record we are selling to close out
      #self.position = 0
      tb = self.total_balance(bar)
      self.store_results(self.trades, date, self.position['{}'.format(stock)], price, stock, last_quantity, tb)

      if self.verbose:
        print("Closed open trades for {} shares of {} at {:0.1f} per share worth {:0.1f} $".format(last_quantity,stock, price, last_quantity * price))
        #print("--------------Final Balance-----------")
        #self.total_balance(bar)
        #returns = (self.capital - self.initial_capital) /self.initial_capital *100
        #print("------------------------------")
        #print("The total capital at end of strategy: {:0.1f}".format(self.capital))
        #print("The strategy returns on investment are {:0.1f} %".format(returns))
        #print("Total trades by startegy are {:0.1f}".format(self.trades))

    #print("=" *50)
    #print("--------------Final Balance-----------")
    #tb = self.total_balance(bar)
    #print("Total balan from tb is ", tb)
    #print('self.capital is ', self.capital)
    #returns = (self.capital - self.initial_capital) /self.initial_capital *100
    #print("The total capital at end of strategy: {:0.1f}".format(self.capital))
    #print("The strategy returns on investment are {:0.1f} %".format(returns))
    #print("Total trades by startegy are {:0.1f}".format(self.trades))
    #print("=" *50)

# %%
class MA_Strategy(Common_Class):

  def go_long(self, bar, stock, quantity = None, dollar = None): # either previously in position or fresh position
    if self.position['{}'.format(stock)] == -1:
      self.position['{}'.format(stock)] = 0
      self.buy_order(bar,stock, quantity = -self.quantity['{}'.format(stock)]) #to clear previous short position and therefore negative quantity.(already in position, thats why negative)
    if quantity:
      self.buy_order (bar, stock, quantity = quantity) # to create new fresh order
    elif dollar:
      if dollar == 'all':
        dollar = self.capital
      else:
        dollar = self.capital/len(self.symbol)
      self.buy_order(bar, stock, dollar = dollar)


  def go_short(self, bar, stock, quantity = None, dollar = None):
    if self.position['{}'.format(stock)] == 1:
      self.position['{}'.format(stock)] = 0
      self.sell_order(bar,stock, quantity = self.quantity['{}'.format(stock)]) #to clear previous long vposition
    if quantity:
      self.sell_order (bar, stock, quantity = quantity) # to create new fresh order
    elif dollar:
      if dollar == 'all':
        dollar = self.capital
      else:
        dollar = self.capital/len(self.symbol)
      self.sell_order(bar, stock, dollar = dollar)

  def run_strategy(self, STMA_window, LTMA_window): # add the parameters according to the strategy
    self.stop = False
    self.trades = 0
    self.capital = self.initial_capital

    #Preparing data with LTMA and STMA so that can check crossovers. Also initialising with 0 quantity and 0 position

    for stock in self.symbol:
      self.quantity['{}'.format(stock)] = 0
      self.position['{}'.format(stock)] = 0

      indicator_1 = SMAIndicator(close = self.all_data['{}'.format(stock)]["Close_Price"], window = STMA_window, fillna= False)
      STMA = indicator_1.sma_indicator()

      indicator_2 = SMAIndicator(close = self.all_data['{}'.format(stock)]["Close_Price"], window = LTMA_window, fillna= False)
      LTMA = indicator_2.sma_indicator()

      self.all_data['{}'.format(stock)]['STMA_{}'.format(stock)] = STMA
      self.all_data['{}'.format(stock)]['LTMA_{}'.format(stock)] = LTMA

    for bar in range(LTMA_window, len(self.all_data['{}'.format(self.symbol[0])])): # from the available data bar to the last data bar
      #Making a func so that no trade if balance goes below 0

      tb = self.total_balance(bar)
      if tb< 0:
        print("negative capital")
        self.last_trade(bar)
        self.stop = True
        break

      for stock in self.symbol:
        date, price = self.return_date_price(bar, stock)

        if self.position['{}'.format(stock)] in [0,-1]: # checking no position or short position
          if self.all_data['{}'.format(stock)]['STMA_{}'.format(stock)].iloc[bar] > self.all_data['{}'.format(stock)]['LTMA_{}'.format(stock)].iloc[bar]:
             self.go_long(bar,stock, dollar = self.capital/len(self.symbol)) # go with equal money # Make sure to enter less than initila capital
             #print("--------")
             continue # as I am storing data for SR calculations. Dont wnat duplication

        if self.position['{}'.format(stock)] in [0,1]: # checking no position or long position
          if self.all_data['{}'.format(stock)]['STMA_{}'.format(stock)].iloc[bar] < self.all_data['{}'.format(stock)]['LTMA_{}'.format(stock)].iloc[bar]:
            self.go_short(bar,stock, dollar =self.capital/len(self.symbol)) # go with equal money
            #print("--------")
            continue

        #-----Storing all the values for calculating Sharpe-----
        store_quantity = abs(self.quantity['{}'.format(stock)]) # so that I want just the positive numbers in my performance table. I will calculate +/- based on position sign
        tb = self.total_balance(bar)
        self.store_results(0, date, self.position['{}'.format(stock)], price, stock, store_quantity, tb)  # I have used continue in previous "if conditions", So if they didnt execute meaning no trade conditions that day ; trade = 0

    if self.stop == False: # to make sure not to run this func 2 times when early exit due to negative balance
      self.last_trade(bar)  # amke sure the crossover happens, give more time

if __name__ == "__main__":
    stocks = ['MSFT', 'AAPL', 'GS', 'WFC', 'XOM', 'CVX', 'PSA', 'O', 'PG', 'KO', 'AMZN', 'IBM', 'AXP', 'JPM','EOG','COP', 'AVB', 'WELL','PEP','COST']
    A = MA_Strategy(stocks, "2020-01-01", "2020-06-01","1d", 10000, 0.00, False)
    A.run_strategy(10,40)
    A.performance()
    A.performance_plots()

  #UnboundLocalError: local variable 'bar' referenced before assignment
  # If duration of test or difference between start date aand end date is less than MA
# Out:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_7444\1730464758.py:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.stored_data = pd.concat([self.stored_data, trade_detail])
# ==================================================
# Performance Metrics
# The total capital at end of strategy: 12338.0
# The annual regular returns: 138.20 %
# The annual regular std deviation: 56.56 %
# The annual Sharpe Ratio: 2.44
# The returns on investment from 2020-01-01 to 2020-06-01 by this strategy is 23.4 %
# The maximum drawdown: 18.46 %
# The maximum drawdown period: 2.00 days
# The annual Sortino Ratio: 4.51
# The total trades taken by the strategy: 108
# ==================================================

# %% [markdown]
# The Bollinger Bands strategy with sector ETF confirmation trades a diversified portfolio of stocks using Bollinger Bands to generate buy and sell signals, but only executes trades when these signals are confirmed by the corresponding sector ETFs, aligning individual stock movements with broader sector trends. By optimizing the Bollinger Bands parameters (window size and standard deviation multiplier) through hyperparameter tuning on historical data, the strategy aims to enhance trade accuracy and achieve better risk-adjusted returns during the testing period.

# %%
from ta.volatility import BollingerBands

class BollingerBandStrategy(Common_Class):

    def __init__(self, symbol, start, end, interval, capital, transaction_cost, verbose=True, window=20, window_dev=2):
        super().__init__(symbol, start, end, interval, capital, transaction_cost, verbose)
        self.window = window if window else 20
        self.window_dev = window_dev if window_dev else 2

        # Sector mapping
        self.sector_mapping = {
            'MSFT': 'Technology',
            'AAPL': 'Technology',
            'GS': 'Financials',
            'WFC': 'Financials',
            'XOM': 'Energy',
            'CVX': 'Energy',
            'PSA': 'Real Estate',
            'O': 'Real Estate',
            'PG': 'Consumer Staples',
            'KO': 'Consumer Staples',
            'AMZN': 'Consumer Discretionary',
            'IBM': 'Technology',
            'AXP': 'Financials',
            'JPM': 'Financials',
            'EOG': 'Energy',
            'COP': 'Energy',
            'AVB': 'Real Estate',
            'WELL': 'Real Estate',
            'PEP': 'Consumer Staples',
            'COST': 'Consumer Staples'
        }

        self.sector_etfs = {
            'Technology': 'XLK',
            'Financials': 'XLF',
            'Energy': 'XLE',
            'Real Estate': 'IYR',
            'Consumer Staples': 'XLP',
            'Consumer Discretionary': 'XLY'
        }

        self.stocks = [s for s in self.symbol if s not in self.sector_etfs.values()]


    def go_long(self, bar, stock, quantity=None, dollar=None):
        if self.position[stock] == -1:
            self.position[stock] = 0
            self.buy_order(bar, stock, quantity=-self.quantity[stock])
        if quantity:
            self.buy_order(bar, stock, quantity=quantity)
        elif dollar:
            if dollar == 'all':
                dollar = self.capital
            else:
                dollar = self.capital / len(self.stocks)
            self.buy_order(bar, stock, dollar=dollar)

    def go_short(self, bar, stock, quantity=None, dollar=None):
        if self.position[stock] == 1:
            self.position[stock] = 0
            self.sell_order(bar, stock, quantity=self.quantity[stock])
        if quantity:
            self.sell_order(bar, stock, quantity=quantity)
        elif dollar:
            if dollar == 'all':
                dollar = self.capital
            else:
                dollar = self.capital / len(self.stocks)
            self.sell_order(bar, stock, dollar=dollar)

    def run_strategy(self):
        self.stop = False
        self.trades = 0
        self.capital = self.initial_capital

        # Compute Bollinger Bands for stocks
        for stock in self.stocks:
            indicator_bb = BollingerBands(
                close=self.all_data[stock]["Close_Price"],
                window=self.window,
                window_dev=self.window_dev
            )
            self.all_data[stock]['bb_middle_band'] = indicator_bb.bollinger_mavg()
            self.all_data[stock]['bb_upper_band'] = indicator_bb.bollinger_hband()
            self.all_data[stock]['bb_lower_band'] = indicator_bb.bollinger_lband()

        # Compute Bollinger Bands for sector ETFs
        for etf in self.sector_etfs.values():
            indicator_bb = BollingerBands(
                close=self.all_data[etf]["Close_Price"],
                window=self.window,
                window_dev=self.window_dev
            )
            self.all_data[etf]['bb_middle_band'] = indicator_bb.bollinger_mavg()
            self.all_data[etf]['bb_upper_band'] = indicator_bb.bollinger_hband()
            self.all_data[etf]['bb_lower_band'] = indicator_bb.bollinger_lband()

        # Run the strategy
        for bar in range(self.window, len(self.all_data[self.stocks[0]])):
            tb = self.total_balance(bar)
            if tb < 0:
                print("Negative capital")
                self.last_trade(bar)
                self.stop = True
                break

            for stock in self.stocks:
                date, price = self.return_date_price(bar, stock)
                sector = self.sector_mapping[stock]
                sector_etf = self.sector_etfs[sector]

                # Stock signals
                price_stock_current = self.all_data[stock]['Close_Price'].iloc[bar]
                price_stock_previous = self.all_data[stock]['Close_Price'].iloc[bar - 1]
                lower_band_stock_current = self.all_data[stock]['bb_lower_band'].iloc[bar]
                lower_band_stock_previous = self.all_data[stock]['bb_lower_band'].iloc[bar - 1]
                upper_band_stock_current = self.all_data[stock]['bb_upper_band'].iloc[bar]
                upper_band_stock_previous = self.all_data[stock]['bb_upper_band'].iloc[bar - 1]

                if (price_stock_previous < lower_band_stock_previous) and (price_stock_current > lower_band_stock_current):
                    signal_stock = 'buy'
                elif (price_stock_previous > upper_band_stock_previous) and (price_stock_current < upper_band_stock_current):
                    signal_stock = 'sell'
                else:
                    signal_stock = 'hold'

                # Sector ETF signals
                price_etf_current = self.all_data[sector_etf]['Close_Price'].iloc[bar]
                price_etf_previous = self.all_data[sector_etf]['Close_Price'].iloc[bar - 1]
                lower_band_etf_current = self.all_data[sector_etf]['bb_lower_band'].iloc[bar]
                lower_band_etf_previous = self.all_data[sector_etf]['bb_lower_band'].iloc[bar - 1]
                upper_band_etf_current = self.all_data[sector_etf]['bb_upper_band'].iloc[bar]
                upper_band_etf_previous = self.all_data[sector_etf]['bb_upper_band'].iloc[bar - 1]

                if (price_etf_previous < lower_band_etf_previous) and (price_etf_current > lower_band_etf_current):
                    signal_etf = 'buy'
                elif (price_etf_previous > upper_band_etf_previous) and (price_etf_current < upper_band_etf_current):
                    signal_etf = 'sell'
                else:
                    signal_etf = 'hold'

                # Proceed if signals agree
                if signal_stock == signal_etf and signal_stock != 'hold':
                    if signal_stock == 'buy':
                        if self.position[stock] <= 0:
                            self.go_long(bar, stock, dollar=self.capital / len(self.stocks))
                    elif signal_stock == 'sell':
                        if self.position[stock] >= 0:
                            self.go_short(bar, stock, dollar=self.capital / len(self.stocks))
                    trade = 1
                else:
                    trade = 0

                # Store results
                store_quantity = abs(self.quantity[stock])
                tb = self.total_balance(bar)
                self.store_results(trade, date, self.position[stock], price, stock, store_quantity, tb)

        if not self.stop:
            self.last_trade(bar)


def hyperparameter_tuning(symbols, initial_capital, transaction_cost, verbose, start_date, end_date, window_range, window_dev_range):
    best_sharpe = float('-inf')
    best_params = None
    tuning_results = []

    for window in window_range:
        for window_dev in window_dev_range:
            print(f"Testing window={window}, window_dev={window_dev}")
            strategy = BollingerBandStrategy(
                symbols,
                start_date,
                end_date,
                "1d",
                initial_capital,
                transaction_cost,
                verbose,
                window=window,
                window_dev=window_dev
            )
            strategy.run_strategy()
            strategy.performance()
            metrics = strategy.metrics
            metrics['window'] = window
            metrics['window_dev'] = window_dev
            tuning_results.append(metrics)
            if metrics['sharpe_ratio'] > best_sharpe:
                best_sharpe = metrics['sharpe_ratio']
                best_params = (window, window_dev)

    return best_params, tuning_results

if __name__ == "__main__":
    # Define stocks and sector ETFs
    stocks = ['MSFT', 'AAPL', 'GS', 'WFC', 'XOM', 'CVX', 'PSA', 'O', 'PG', 'KO',
              'AMZN', 'IBM', 'AXP', 'JPM', 'EOG', 'COP', 'AVB', 'WELL', 'PEP', 'COST']
    sector_etfs = {
        'Technology': 'XLK',
        'Financials': 'XLF',
        'Energy': 'XLE',
        'Real Estate': 'IYR',
        'Consumer Staples': 'XLP',
        'Consumer Discretionary': 'XLY'
    }
    symbols = stocks + list(sector_etfs.values())
    initial_capital = 500000
    transaction_cost = 0.00
    verbose = True

    # # Training period
    # train_start_date = "2010-01-01"
    # train_end_date = "2016-12-31"

    # # Hyperparameter ranges
    # window_range = [10, 20, 30, 40, 50]
    # window_dev_range = [1, 1.5, 2, 2.5, 3]

    # # Perform hyperparameter tuning
    # best_params, tuning_results = hyperparameter_tuning(
    #     symbols,
    #     initial_capital,
    #     transaction_cost,
    #     verbose,
    #     train_start_date,
    #     train_end_date,
    #     window_range,
    #     window_dev_range
    # )

    # print(f"Best parameters: window={best_params[0]}, window_dev={best_params[1]}")

    # if best_params:
    #     window = best_params[0]
    #     window_dev = best_params[1]
    # else:
    window = 20
    window_dev = 2

    # Testing period
    test_start_date = "2017-01-01"
    test_end_date = "2019-12-31"

    # Run strategy with best parameters on testing period
    strategy = BollingerBandStrategy(
        symbols,
        test_start_date,
        test_end_date,
        "1d",
        initial_capital,
        transaction_cost,
        verbose,
        window=window,
        window_dev=window_dev
    )
    strategy.run_strategy()
    strategy.performance()
    strategy.performance_plots()
# Out:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_7444\3884642560.py:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.stored_data = pd.concat([self.stored_data, trade_detail])
# Bought 309 shares of CVX at 80.8 per share worth 24957.1 $
# Total quantity for CVX is 309
# Date :2017-02-02 | Realised Balance: 475042.9
# Bought 174 shares of AVB at 136.2 per share worth 23690.7 $
# Total quantity for AVB is 174
# Date :2017-02-02 | Realised Balance: 451352.3
# Bought 298 shares of EOG at 75.6 per share worth 22530.6 $
# Total quantity for EOG is 298
# Date :2017-02-08 | Realised Balance: 428821.7
# Sold 518 shares of O at 41.3 per share worth 21416.6 $
# Total quantity for O is -518
# Date :2017-02-14 | Realised Balance: 450238.3
# Sold 106 shares of GS at 211.7 per share worth 22440.3 $
# Total quantity for GS is -106
# Date :2017-02-16 | Realised Balance: 472678.6
# Sold 505 shares of WFC at 46.8 per share worth 23632.9 $
# Total quantity for WFC is -505
# Date :2017-02-16 | Realised Balance: 496311.5
# Sold 348 shares of AXP at 71.3 per share worth 24800.0 $
# Total quantity for AXP is -348
# Date :2017-02-16 | Realised Balance: 521111.5
# Sold 172 shares of COST at 150.8 per share worth 25932.0 $
# Total quantity for COST is -172
# Date :2017-02-16 | Realised Balance: 547043.5
# Sold 165 shares of PSA at 165.4 per share worth 27284.2 $
# Total quantity for PSA is -165
# Date :2017-02-22 | Realised Balance: 574327.6
# Sold 386 shares of PG at 74.2 per share worth 28647.4 $
# Total quantity for PG is -386
# Date :2017-02-22 | Realised Balance: 602975.0
# Sold 704 shares of AMZN at 42.8 per share worth 30117.5 $
# Total quantity for AMZN is -704
# Date :2017-02-22 | Realised Balance: 633092.5
# Sold 362 shares of PEP at 87.4 per share worth 31634.2 $
# Total quantity for PEP is -362
# Date :2017-02-22 | Realised Balance: 664726.7
# Bought 904 shares of COP at 36.7 per share worth 33207.2 $
# Total quantity for COP is 904
# Date :2017-03-09 | Realised Balance: 631519.5
# Bought 505 shares of WFC at 45.0 per share worth 22701.7 $
# Total quantity for WFC is 0
# Date :2017-03-24 | Realised Balance: 608817.8
# Bought 677 shares of WFC at 45.0 per share worth 30433.8 $
# Total quantity for WFC is 677
# Date :2017-03-24 | Realised Balance: 578384.0
# Bought 410 shares of JPM at 70.4 per share worth 28866.4 $
# Total quantity for JPM is 410
# Date :2017-03-24 | Realised Balance: 549517.6
# Bought 237 shares of IBM at 115.7 per share worth 27428.3 $
# Total quantity for IBM is 237
# Date :2017-04-17 | Realised Balance: 522089.3
# Bought 348 shares of AXP at 69.0 per share worth 24012.3 $
# Total quantity for AXP is 0
# Date :2017-04-17 | Realised Balance: 498077.0
# Bought 360 shares of AXP at 69.0 per share worth 24840.4 $
# Total quantity for AXP is 360
# Date :2017-04-17 | Realised Balance: 473236.7
# Sold 174 shares of AVB at 147.4 per share worth 25655.5 $
# Total quantity for AVB is 0
# Date :2017-04-18 | Realised Balance: 498892.2
# Sold 169 shares of AVB at 147.4 per share worth 24918.3 $
# Total quantity for AVB is -169
# Date :2017-04-18 | Realised Balance: 523810.4
# Sold 767 shares of KO at 34.1 per share worth 26163.1 $
# Total quantity for KO is -767
# Date :2017-04-19 | Realised Balance: 549973.5
# Bought 481 shares of XOM at 57.1 per share worth 27459.0 $
# Total quantity for XOM is 481
# Date :2017-04-20 | Realised Balance: 522514.5
# Sold 763 shares of AAPL at 34.2 per share worth 26120.3 $
# Total quantity for AAPL is -763
# Date :2017-05-03 | Realised Balance: 548634.8
# Bought 518 shares of O at 38.9 per share worth 20161.2 $
# Total quantity for O is 0
# Date :2017-05-05 | Realised Balance: 528473.6
# Bought 678 shares of O at 38.9 per share worth 26388.6 $
# Total quantity for O is 678
# Date :2017-05-05 | Realised Balance: 502085.0
# Sold 678 shares of O at 38.2 per share worth 25905.1 $
# Total quantity for O is 0
# Date :2017-06-05 | Realised Balance: 527990.1
# Sold 690 shares of O at 38.2 per share worth 26363.6 $
# Total quantity for O is -690
# Date :2017-06-05 | Realised Balance: 554353.7
# Bought 386 shares of PG at 71.3 per share worth 27512.4 $
# Total quantity for PG is 0
# Date :2017-06-30 | Realised Balance: 526841.3
# Bought 369 shares of PG at 71.3 per share worth 26300.7 $
# Total quantity for PG is 369
# Date :2017-06-30 | Realised Balance: 500540.5
# Bought 362 shares of PEP at 93.5 per share worth 33852.4 $
# Total quantity for PEP is 0
# Date :2017-06-30 | Realised Balance: 466688.1
# Bought 249 shares of PEP at 93.5 per share worth 23285.2 $
# Total quantity for PEP is 249
# Date :2017-06-30 | Realised Balance: 443402.8
# Bought 165 shares of PSA at 153.7 per share worth 25365.4 $
# Total quantity for PSA is 0
# Date :2017-07-12 | Realised Balance: 418037.4
# Bought 135 shares of PSA at 153.7 per share worth 20753.5 $
# Total quantity for PSA is 135
# Date :2017-07-12 | Realised Balance: 397283.9
# Bought 169 shares of AVB at 147.2 per share worth 24880.9 $
# Total quantity for AVB is 0
# Date :2017-07-12 | Realised Balance: 372403.0
# Bought 126 shares of AVB at 147.2 per share worth 18550.3 $
# Total quantity for AVB is 126
# Date :2017-07-12 | Realised Balance: 353852.7
# Sold 298 shares of EOG at 72.4 per share worth 21578.8 $
# Total quantity for EOG is 0
# Date :2017-07-20 | Realised Balance: 375431.5
# Sold 259 shares of EOG at 72.4 per share worth 18754.7 $
# Total quantity for EOG is -259
# Date :2017-07-20 | Realised Balance: 394186.2
# Sold 369 shares of PG at 74.4 per share worth 27437.8 $
# Total quantity for PG is 0
# Date :2017-07-28 | Realised Balance: 421624.0
# Sold 283 shares of PG at 74.4 per share worth 21043.1 $
# Total quantity for PG is -283
# Date :2017-07-28 | Realised Balance: 442667.1
# Sold 249 shares of PEP at 94.4 per share worth 23511.1 $
# Total quantity for PEP is 0
# Date :2017-07-28 | Realised Balance: 466178.2
# Sold 246 shares of PEP at 94.4 per share worth 23227.8 $
# Total quantity for PEP is -246
# Date :2017-07-28 | Realised Balance: 489406.0
# Bought 367 shares of MSFT at 66.6 per share worth 24447.8 $
# Total quantity for MSFT is 367
# Date :2017-08-11 | Realised Balance: 464958.2
# Bought 425 shares of WELL at 54.7 per share worth 23234.6 $
# Total quantity for WELL is 425
# Date :2017-08-14 | Realised Balance: 441723.6
# Bought 259 shares of EOG at 65.0 per share worth 16838.4 $
# Total quantity for EOG is 0
# Date :2017-08-18 | Realised Balance: 424885.2
# Bought 326 shares of EOG at 65.0 per share worth 21194.3 $
# Total quantity for EOG is 326
# Date :2017-08-18 | Realised Balance: 403690.9
# Sold 367 shares of MSFT at 68.3 per share worth 25066.2 $
# Total quantity for MSFT is 0
# Date :2017-09-01 | Realised Balance: 428757.1
# Sold 313 shares of MSFT at 68.3 per share worth 21378.0 $
# Total quantity for MSFT is -313
# Date :2017-09-01 | Realised Balance: 450135.1
# Bought 106 shares of GS at 186.1 per share worth 19725.0 $
# Total quantity for GS is 0
# Date :2017-09-08 | Realised Balance: 430410.1
# Bought 115 shares of GS at 186.1 per share worth 21399.7 $
# Total quantity for GS is 115
# Date :2017-09-08 | Realised Balance: 409010.4
# Sold 309 shares of CVX at 82.1 per share worth 25380.4 $
# Total quantity for CVX is 0
# Date :2017-09-08 | Realised Balance: 434390.7
# Sold 264 shares of CVX at 82.1 per share worth 21684.2 $
# Total quantity for CVX is -264
# Date :2017-09-08 | Realised Balance: 456074.9
# Sold 425 shares of WELL at 56.6 per share worth 24073.3 $
# Total quantity for WELL is 0
# Date :2017-09-12 | Realised Balance: 480148.2
# Sold 423 shares of WELL at 56.6 per share worth 23960.0 $
# Total quantity for WELL is -423
# Date :2017-09-12 | Realised Balance: 504108.2
# Sold 135 shares of PSA at 163.6 per share worth 22081.6 $
# Total quantity for PSA is 0
# Date :2017-10-16 | Realised Balance: 526189.7
# Sold 160 shares of PSA at 163.6 per share worth 26170.7 $
# Total quantity for PSA is -160
# Date :2017-10-16 | Realised Balance: 552360.5
# Sold 360 shares of AXP at 84.8 per share worth 30534.6 $
# Total quantity for AXP is 0
# Date :2017-10-25 | Realised Balance: 582895.1
# Sold 343 shares of AXP at 84.8 per share worth 29092.7 $
# Total quantity for AXP is -343
# Date :2017-10-25 | Realised Balance: 611987.8
# Bought 160 shares of PSA at 155.6 per share worth 24888.4 $
# Total quantity for PSA is 0
# Date :2017-10-27 | Realised Balance: 587099.4
# Bought 188 shares of PSA at 155.6 per share worth 29243.9 $
# Total quantity for PSA is 188
# Date :2017-10-27 | Realised Balance: 557855.5
# Bought 423 shares of WELL at 51.2 per share worth 21645.9 $
# Total quantity for WELL is 0
# Date :2017-10-27 | Realised Balance: 536209.7
# Bought 523 shares of WELL at 51.2 per share worth 26763.1 $
# Total quantity for WELL is 523
# Date :2017-10-27 | Realised Balance: 509446.6
# Sold 326 shares of EOG at 80.8 per share worth 26341.5 $
# Total quantity for EOG is 0
# Date :2017-11-08 | Realised Balance: 535788.1
# Sold 331 shares of EOG at 80.8 per share worth 26745.5 $
# Total quantity for EOG is -331
# Date :2017-11-08 | Realised Balance: 562533.5
# Bought 313 shares of MSFT at 75.7 per share worth 23708.3 $
# Total quantity for MSFT is 0
# Date :2017-12-05 | Realised Balance: 538825.3
# Bought 355 shares of MSFT at 75.7 per share worth 26889.6 $
# Total quantity for MSFT is 355
# Date :2017-12-05 | Realised Balance: 511935.7
# Sold 115 shares of GS at 213.4 per share worth 24542.6 $
# Total quantity for GS is 0
# Date :2017-12-05 | Realised Balance: 536478.3
# Sold 125 shares of GS at 213.4 per share worth 26676.7 $
# Total quantity for GS is -125
# Date :2017-12-05 | Realised Balance: 563155.0
# Sold 410 shares of JPM at 86.7 per share worth 35562.1 $
# Total quantity for JPM is 0
# Date :2017-12-05 | Realised Balance: 598717.1
# Sold 345 shares of JPM at 86.7 per share worth 29924.2 $
# Total quantity for JPM is -345
# Date :2017-12-05 | Realised Balance: 628641.3
# Bought 690 shares of O at 38.7 per share worth 26701.7 $
# Total quantity for O is 0
# Date :2017-12-07 | Realised Balance: 601939.6
# Bought 777 shares of O at 38.7 per share worth 30068.5 $
# Total quantity for O is 777
# Date :2017-12-07 | Realised Balance: 571871.1
# Sold 904 shares of COP at 44.7 per share worth 40396.8 $
# Total quantity for COP is 0
# Date :2017-12-27 | Realised Balance: 612267.9
# Sold 685 shares of COP at 44.7 per share worth 30610.4 $
# Total quantity for COP is -685
# Date :2017-12-27 | Realised Balance: 642878.4
# Sold 677 shares of WFC at 51.0 per share worth 34543.3 $
# Total quantity for WFC is 0
# Date :2018-01-08 | Realised Balance: 677421.7
# Sold 663 shares of WFC at 51.0 per share worth 33828.9 $
# Total quantity for WFC is -663
# Date :2018-01-08 | Realised Balance: 711250.6
# Sold 355 shares of MSFT at 83.6 per share worth 29694.2 $
# Total quantity for MSFT is 0
# Date :2018-01-18 | Realised Balance: 740944.8
# Sold 442 shares of MSFT at 83.6 per share worth 36971.4 $
# Total quantity for MSFT is -442
# Date :2018-01-18 | Realised Balance: 777916.2
# Bought 763 shares of AAPL at 38.4 per share worth 29295.5 $
# Total quantity for AAPL is 0
# Date :2018-02-06 | Realised Balance: 748620.7
# Bought 974 shares of AAPL at 38.4 per share worth 37396.9 $
# Total quantity for AAPL is 974
# Date :2018-02-06 | Realised Balance: 711223.8
# Bought 283 shares of PG at 68.5 per share worth 19380.3 $
# Total quantity for PG is 0
# Date :2018-02-07 | Realised Balance: 691843.5
# Bought 505 shares of PG at 68.5 per share worth 34583.2 $
# Total quantity for PG is 505
# Date :2018-02-07 | Realised Balance: 657260.2
# Bought 442 shares of MSFT at 81.9 per share worth 36183.5 $
# Total quantity for MSFT is 0
# Date :2018-02-09 | Realised Balance: 621076.7
# Bought 379 shares of MSFT at 81.9 per share worth 31026.1 $
# Total quantity for MSFT is 379
# Date :2018-02-09 | Realised Balance: 590050.6
# Bought 663 shares of WFC at 46.4 per share worth 30788.9 $
# Total quantity for WFC is 0
# Date :2018-02-09 | Realised Balance: 559261.7
# Bought 602 shares of WFC at 46.4 per share worth 27956.1 $
# Total quantity for WFC is 602
# Date :2018-02-09 | Realised Balance: 531305.5
# Bought 343 shares of AXP at 83.5 per share worth 28630.4 $
# Total quantity for AXP is 0
# Date :2018-02-09 | Realised Balance: 502675.1
# Bought 301 shares of AXP at 83.5 per share worth 25124.6 $
# Total quantity for AXP is 301
# Date :2018-02-09 | Realised Balance: 477550.5
# Bought 345 shares of JPM at 90.8 per share worth 31309.2 $
# Total quantity for JPM is 0
# Date :2018-02-09 | Realised Balance: 446241.3
# Bought 245 shares of JPM at 90.8 per share worth 22234.1 $
# Total quantity for JPM is 245
# Date :2018-02-09 | Realised Balance: 424007.2
# Bought 246 shares of PEP at 91.3 per share worth 22455.9 $
# Total quantity for PEP is 0
# Date :2018-02-09 | Realised Balance: 401551.3
# Bought 219 shares of PEP at 91.3 per share worth 19991.2 $
# Total quantity for PEP is 219
# Date :2018-02-09 | Realised Balance: 381560.1
# Bought 172 shares of COST at 162.8 per share worth 27995.4 $
# Total quantity for COST is 0
# Date :2018-02-09 | Realised Balance: 353564.7
# Bought 108 shares of COST at 162.8 per share worth 17578.5 $
# Total quantity for COST is 108
# Date :2018-02-09 | Realised Balance: 335986.2
# Bought 331 shares of EOG at 80.0 per share worth 26478.8 $
# Total quantity for EOG is 0
# Date :2018-02-12 | Realised Balance: 309507.4
# Bought 193 shares of EOG at 80.0 per share worth 15439.3 $
# Total quantity for EOG is 193
# Date :2018-02-12 | Realised Balance: 294068.1
# Bought 685 shares of COP at 43.2 per share worth 29568.3 $
# Total quantity for COP is 0
# Date :2018-02-12 | Realised Balance: 264499.7
# Bought 306 shares of COP at 43.2 per share worth 13208.6 $
# Total quantity for COP is 306
# Date :2018-02-12 | Realised Balance: 251291.1
# Bought 125 shares of GS at 219.7 per share worth 27457.2 $
# Total quantity for GS is 0
# Date :2018-03-26 | Realised Balance: 223833.9
# Bought 50 shares of GS at 219.7 per share worth 10982.9 $
# Total quantity for GS is 50
# Date :2018-03-26 | Realised Balance: 212851.0
# Bought 767 shares of KO at 34.8 per share worth 26705.1 $
# Total quantity for KO is 0
# Date :2018-03-26 | Realised Balance: 186145.9
# Bought 267 shares of KO at 34.8 per share worth 9296.3 $
# Total quantity for KO is 267
# Date :2018-03-26 | Realised Balance: 176849.6
# Sold 188 shares of PSA at 161.0 per share worth 30273.1 $
# Total quantity for PSA is 0
# Date :2018-05-08 | Realised Balance: 207122.7
# Sold 64 shares of PSA at 161.0 per share worth 10305.7 $
# Total quantity for PSA is -64
# Date :2018-05-08 | Realised Balance: 217428.4
# Sold 379 shares of MSFT at 91.1 per share worth 34537.2 $
# Total quantity for MSFT is 0
# Date :2018-05-11 | Realised Balance: 251965.6
# Sold 138 shares of MSFT at 91.1 per share worth 12575.6 $
# Total quantity for MSFT is -138
# Date :2018-05-11 | Realised Balance: 264541.2
# Sold 602 shares of WFC at 45.4 per share worth 27323.6 $
# Total quantity for WFC is 0
# Date :2018-05-11 | Realised Balance: 291864.8
# Sold 321 shares of WFC at 45.4 per share worth 14569.6 $
# Total quantity for WFC is -321
# Date :2018-05-11 | Realised Balance: 306434.3
# Sold 777 shares of O at 38.2 per share worth 29673.4 $
# Total quantity for O is 0
# Date :2018-05-11 | Realised Balance: 336107.8
# Sold 440 shares of O at 38.2 per share worth 16803.5 $
# Total quantity for O is -440
# Date :2018-05-11 | Realised Balance: 352911.3
# Sold 245 shares of JPM at 94.4 per share worth 23122.6 $
# Total quantity for JPM is 0
# Date :2018-05-11 | Realised Balance: 376033.9
# Sold 199 shares of JPM at 94.4 per share worth 18781.2 $
# Total quantity for JPM is -199
# Date :2018-05-11 | Realised Balance: 394815.1
# Sold 306 shares of COP at 56.7 per share worth 17345.6 $
# Total quantity for COP is 0
# Date :2018-05-16 | Realised Balance: 412160.7
# Sold 363 shares of COP at 56.7 per share worth 20576.7 $
# Total quantity for COP is -363
# Date :2018-05-16 | Realised Balance: 432737.4
# Sold 267 shares of KO at 35.1 per share worth 9363.8 $
# Total quantity for KO is 0
# Date :2018-05-31 | Realised Balance: 442101.2
# Sold 630 shares of KO at 35.1 per share worth 22094.4 $
# Total quantity for KO is -630
# Date :2018-05-31 | Realised Balance: 464195.6
# Sold 523 shares of WELL at 45.9 per share worth 24013.0 $
# Total quantity for WELL is 0
# Date :2018-05-31 | Realised Balance: 488208.6
# Sold 531 shares of WELL at 45.9 per share worth 24380.3 $
# Total quantity for WELL is -531
# Date :2018-05-31 | Realised Balance: 512588.9
# Sold 219 shares of PEP at 83.7 per share worth 18326.1 $
# Total quantity for PEP is 0
# Date :2018-05-31 | Realised Balance: 530915.0
# Sold 317 shares of PEP at 83.7 per share worth 26526.8 $
# Total quantity for PEP is -317
# Date :2018-05-31 | Realised Balance: 557441.9
# Sold 974 shares of AAPL at 45.9 per share worth 44729.9 $
# Total quantity for AAPL is 0
# Date :2018-06-07 | Realised Balance: 602171.8
# Sold 655 shares of AAPL at 45.9 per share worth 30080.2 $
# Total quantity for AAPL is -655
# Date :2018-06-07 | Realised Balance: 632251.9
# Sold 505 shares of PG at 64.6 per share worth 32613.1 $
# Total quantity for PG is 0
# Date :2018-06-13 | Realised Balance: 664865.0
# Sold 514 shares of PG at 64.6 per share worth 33194.3 $
# Total quantity for PG is -514
# Date :2018-06-13 | Realised Balance: 698059.3
# Sold 108 shares of COST at 184.9 per share worth 19964.8 $
# Total quantity for COST is 0
# Date :2018-06-13 | Realised Balance: 718024.1
# Sold 194 shares of COST at 184.9 per share worth 35862.7 $
# Total quantity for COST is -194
# Date :2018-06-13 | Realised Balance: 753886.8
# Bought 138 shares of MSFT at 92.4 per share worth 12750.3 $
# Total quantity for MSFT is 0
# Date :2018-06-28 | Realised Balance: 741136.5
# Bought 401 shares of MSFT at 92.4 per share worth 37049.8 $
# Total quantity for MSFT is 401
# Date :2018-06-28 | Realised Balance: 704086.7
# Bought 321 shares of WFC at 44.7 per share worth 14350.1 $
# Total quantity for WFC is 0
# Date :2018-06-28 | Realised Balance: 689736.6
# Bought 771 shares of WFC at 44.7 per share worth 34467.2 $
# Total quantity for WFC is 771
# Date :2018-06-28 | Realised Balance: 655269.4
# Bought 199 shares of JPM at 87.0 per share worth 17308.2 $
# Total quantity for JPM is 0
# Date :2018-06-28 | Realised Balance: 637961.2
# Bought 366 shares of JPM at 87.0 per share worth 31833.2 $
# Total quantity for JPM is 366
# Date :2018-06-28 | Realised Balance: 606128.0
# Sold 126 shares of AVB at 139.0 per share worth 17509.5 $
# Total quantity for AVB is 0
# Date :2018-07-02 | Realised Balance: 623637.5
# Sold 224 shares of AVB at 139.0 per share worth 31128.0 $
# Total quantity for AVB is -224
# Date :2018-07-02 | Realised Balance: 654765.5
# Sold 481 shares of XOM at 61.1 per share worth 29386.2 $
# Total quantity for XOM is 0
# Date :2018-07-11 | Realised Balance: 684151.7
# Sold 559 shares of XOM at 61.1 per share worth 34151.6 $
# Total quantity for XOM is -559
# Date :2018-07-11 | Realised Balance: 718303.3
# Sold 301 shares of AXP at 91.8 per share worth 27641.2 $
# Total quantity for AXP is 0
# Date :2018-07-19 | Realised Balance: 745944.5
# Sold 406 shares of AXP at 91.8 per share worth 37283.5 $
# Total quantity for AXP is -406
# Date :2018-07-19 | Realised Balance: 783228.0
# Sold 366 shares of JPM at 91.6 per share worth 33519.1 $
# Total quantity for JPM is 0
# Date :2018-07-19 | Realised Balance: 816747.0
# Sold 445 shares of JPM at 91.6 per share worth 40754.1 $
# Total quantity for JPM is -445
# Date :2018-07-19 | Realised Balance: 857501.1
# Bought 264 shares of CVX at 90.7 per share worth 23938.1 $
# Total quantity for CVX is 0
# Date :2018-08-17 | Realised Balance: 833563.0
# Bought 459 shares of CVX at 90.7 per share worth 41619.7 $
# Total quantity for CVX is 459
# Date :2018-08-17 | Realised Balance: 791943.3
# Sold 50 shares of GS at 209.6 per share worth 10480.8 $
# Total quantity for GS is 0
# Date :2018-08-28 | Realised Balance: 802424.1
# Sold 191 shares of GS at 209.6 per share worth 40036.5 $
# Total quantity for GS is -191
# Date :2018-08-28 | Realised Balance: 842460.6
# Bought 64 shares of PSA at 160.2 per share worth 10250.5 $
# Total quantity for PSA is 0
# Date :2018-09-20 | Realised Balance: 832210.1
# Bought 259 shares of PSA at 160.2 per share worth 41482.4 $
# Total quantity for PSA is 259
# Date :2018-09-20 | Realised Balance: 790727.7
# Bought 440 shares of O at 41.9 per share worth 18452.1 $
# Total quantity for O is 0
# Date :2018-09-20 | Realised Balance: 772275.6
# Bought 920 shares of O at 41.9 per share worth 38581.6 $
# Total quantity for O is 920
# Date :2018-09-20 | Realised Balance: 733694.0
# Bought 531 shares of WELL at 52.9 per share worth 28109.9 $
# Total quantity for WELL is 0
# Date :2018-09-20 | Realised Balance: 705584.1
# Bought 666 shares of WELL at 52.9 per share worth 35256.5 $
# Total quantity for WELL is 666
# Date :2018-09-20 | Realised Balance: 670327.5
# Sold 459 shares of CVX at 93.9 per share worth 43085.9 $
# Total quantity for CVX is 0
# Date :2018-09-26 | Realised Balance: 713413.5
# Sold 380 shares of CVX at 93.9 per share worth 35670.3 $
# Total quantity for CVX is -380
# Date :2018-09-26 | Realised Balance: 749083.7
# Bought 224 shares of AVB at 148.8 per share worth 33327.8 $
# Total quantity for AVB is 0
# Date :2018-09-28 | Realised Balance: 715755.9
# Bought 240 shares of AVB at 148.8 per share worth 35708.4 $
# Total quantity for AVB is 240
# Date :2018-09-28 | Realised Balance: 680047.5
# Bought 704 shares of AMZN at 89.4 per share worth 62959.1 $
# Total quantity for AMZN is 0
# Date :2018-10-12 | Realised Balance: 617088.4
# Bought 345 shares of AMZN at 89.4 per share worth 30853.5 $
# Total quantity for AMZN is 345
# Date :2018-10-12 | Realised Balance: 586234.9
# Bought 363 shares of COP at 60.4 per share worth 21930.3 $
# Total quantity for COP is 0
# Date :2018-10-12 | Realised Balance: 564304.6
# Bought 467 shares of COP at 60.4 per share worth 28213.4 $
# Total quantity for COP is 467
# Date :2018-10-12 | Realised Balance: 536091.2
# Bought 514 shares of PG at 68.3 per share worth 35098.7 $
# Total quantity for PG is 0
# Date :2018-10-15 | Realised Balance: 500992.5
# Bought 366 shares of PG at 68.3 per share worth 24992.4 $
# Total quantity for PG is 366
# Date :2018-10-15 | Realised Balance: 476000.1
# Bought 630 shares of KO at 37.3 per share worth 23479.3 $
# Total quantity for KO is 0
# Date :2018-10-15 | Realised Balance: 452520.8
# Bought 607 shares of KO at 37.3 per share worth 22622.1 $
# Total quantity for KO is 607
# Date :2018-10-15 | Realised Balance: 429898.6
# Bought 559 shares of XOM at 60.7 per share worth 33923.1 $
# Total quantity for XOM is 0
# Date :2018-10-16 | Realised Balance: 395975.5
# Bought 326 shares of XOM at 60.7 per share worth 19783.4 $
# Total quantity for XOM is 326
# Date :2018-10-16 | Realised Balance: 376192.1
# Bought 445 shares of JPM at 91.2 per share worth 40565.2 $
# Total quantity for JPM is 0
# Date :2018-10-16 | Realised Balance: 335626.9
# Bought 184 shares of JPM at 91.2 per share worth 16773.0 $
# Total quantity for JPM is 184
# Date :2018-10-16 | Realised Balance: 318853.8
# Bought 191 shares of GS at 185.7 per share worth 35468.9 $
# Total quantity for GS is 0
# Date :2018-10-25 | Realised Balance: 283385.0
# Bought 76 shares of GS at 185.7 per share worth 14113.3 $
# Total quantity for GS is 76
# Date :2018-10-25 | Realised Balance: 269271.7
# Bought 380 shares of CVX at 85.9 per share worth 32637.1 $
# Total quantity for CVX is 0
# Date :2018-10-25 | Realised Balance: 236634.6
# Bought 137 shares of CVX at 85.9 per share worth 11766.5 $
# Total quantity for CVX is 137
# Date :2018-10-25 | Realised Balance: 224868.1
# Bought 655 shares of AAPL at 42.3 per share worth 27679.3 $
# Total quantity for AAPL is 0
# Date :2018-11-21 | Realised Balance: 197188.8
# Bought 233 shares of AAPL at 42.3 per share worth 9846.2 $
# Total quantity for AAPL is 233
# Date :2018-11-21 | Realised Balance: 187342.6
# Sold 666 shares of WELL at 59.0 per share worth 39278.3 $
# Total quantity for WELL is 0
# Date :2018-12-04 | Realised Balance: 226620.9
# Sold 192 shares of WELL at 59.0 per share worth 11323.5 $
# Total quantity for WELL is -192
# Date :2018-12-04 | Realised Balance: 237944.4
# Sold 259 shares of PSA at 167.3 per share worth 43327.7 $
# Total quantity for PSA is 0
# Date :2018-12-07 | Realised Balance: 281272.1
# Sold 84 shares of PSA at 167.3 per share worth 14052.2 $
# Total quantity for PSA is -84
# Date :2018-12-07 | Realised Balance: 295324.3
# Bought 84 shares of PSA at 161.0 per share worth 13522.4 $
# Total quantity for PSA is 0
# Date :2018-12-18 | Realised Balance: 281801.9
# Bought 87 shares of PSA at 161.0 per share worth 14005.4 $
# Total quantity for PSA is 87
# Date :2018-12-18 | Realised Balance: 267796.5
# Bought 192 shares of WELL at 56.5 per share worth 10847.8 $
# Total quantity for WELL is 0
# Date :2018-12-26 | Realised Balance: 256948.7
# Bought 227 shares of WELL at 56.5 per share worth 12825.3 $
# Total quantity for WELL is 227
# Date :2018-12-26 | Realised Balance: 244123.4
# Bought 317 shares of PEP at 91.9 per share worth 29131.5 $
# Total quantity for PEP is 0
# Date :2018-12-26 | Realised Balance: 214992.0
# Bought 116 shares of PEP at 91.9 per share worth 10660.1 $
# Total quantity for PEP is 116
# Date :2018-12-26 | Realised Balance: 204331.9
# Sold 76 shares of GS at 172.2 per share worth 13089.1 $
# Total quantity for GS is 0
# Date :2019-01-22 | Realised Balance: 217421.0
# Sold 63 shares of GS at 172.2 per share worth 10850.2 $
# Total quantity for GS is -63
# Date :2019-01-22 | Realised Balance: 228271.2
# Sold 366 shares of PG at 84.4 per share worth 30902.5 $
# Total quantity for PG is 0
# Date :2019-02-05 | Realised Balance: 259173.7
# Sold 153 shares of PG at 84.4 per share worth 12918.2 $
# Total quantity for PG is -153
# Date :2019-02-05 | Realised Balance: 272091.9
# Sold 116 shares of PEP at 95.8 per share worth 11109.8 $
# Total quantity for PEP is 0
# Date :2019-02-05 | Realised Balance: 283201.7
# Sold 147 shares of PEP at 95.8 per share worth 14078.8 $
# Total quantity for PEP is -147
# Date :2019-02-05 | Realised Balance: 297280.5
# Sold 326 shares of XOM at 56.8 per share worth 18522.1 $
# Total quantity for XOM is 0
# Date :2019-02-06 | Realised Balance: 315802.6
# Sold 277 shares of XOM at 56.8 per share worth 15738.1 $
# Total quantity for XOM is -277
# Date :2019-02-06 | Realised Balance: 331540.7
# Sold 137 shares of CVX at 92.4 per share worth 12658.8 $
# Total quantity for CVX is 0
# Date :2019-02-06 | Realised Balance: 344199.6
# Sold 186 shares of CVX at 92.4 per share worth 17186.5 $
# Total quantity for CVX is -186
# Date :2019-02-06 | Realised Balance: 361386.1
# Sold 233 shares of AAPL at 40.9 per share worth 9521.0 $
# Total quantity for AAPL is 0
# Date :2019-02-07 | Realised Balance: 370907.0
# Sold 453 shares of AAPL at 40.9 per share worth 18510.7 $
# Total quantity for AAPL is -453
# Date :2019-02-07 | Realised Balance: 389417.7
# Sold 920 shares of O at 53.3 per share worth 49018.9 $
# Total quantity for O is 0
# Date :2019-03-15 | Realised Balance: 438436.6
# Sold 411 shares of O at 53.3 per share worth 21898.7 $
# Total quantity for O is -411
# Date :2019-03-15 | Realised Balance: 460335.3
# Sold 240 shares of AVB at 164.8 per share worth 39556.4 $
# Total quantity for AVB is 0
# Date :2019-03-15 | Realised Balance: 499891.7
# Sold 151 shares of AVB at 164.8 per share worth 24887.6 $
# Total quantity for AVB is -151
# Date :2019-03-15 | Realised Balance: 524779.3
# Sold 227 shares of WELL at 63.9 per share worth 14512.1 $
# Total quantity for WELL is 0
# Date :2019-03-15 | Realised Balance: 539291.3
# Sold 421 shares of WELL at 63.9 per share worth 26914.4 $
# Total quantity for WELL is -421
# Date :2019-03-15 | Realised Balance: 566205.7
# Sold 184 shares of JPM at 90.4 per share worth 16625.9 $
# Total quantity for JPM is 0
# Date :2019-03-19 | Realised Balance: 582831.6
# Sold 322 shares of JPM at 90.4 per share worth 29095.3 $
# Total quantity for JPM is -322
# Date :2019-03-19 | Realised Balance: 611927.0
# Sold 401 shares of MSFT at 111.5 per share worth 44697.1 $
# Total quantity for MSFT is 0
# Date :2019-03-20 | Realised Balance: 656624.1
# Sold 294 shares of MSFT at 111.5 per share worth 32770.4 $
# Total quantity for MSFT is -294
# Date :2019-03-20 | Realised Balance: 689394.5
# Sold 345 shares of AMZN at 88.2 per share worth 30442.3 $
# Total quantity for AMZN is 0
# Date :2019-03-22 | Realised Balance: 719836.8
# Sold 407 shares of AMZN at 88.2 per share worth 35913.1 $
# Total quantity for AMZN is -407
# Date :2019-03-22 | Realised Balance: 755749.9
# Bought 63 shares of GS at 166.8 per share worth 10508.8 $
# Total quantity for GS is 0
# Date :2019-03-26 | Realised Balance: 745241.1
# Bought 223 shares of GS at 166.8 per share worth 37197.9 $
# Total quantity for GS is 223
# Date :2019-03-26 | Realised Balance: 708043.2
# Bought 322 shares of JPM at 84.5 per share worth 27221.0 $
# Total quantity for JPM is 0
# Date :2019-03-26 | Realised Balance: 680822.1
# Bought 402 shares of JPM at 84.5 per share worth 33984.0 $
# Total quantity for JPM is 402
# Date :2019-03-26 | Realised Balance: 646838.1
# Bought 151 shares of AVB at 163.7 per share worth 24721.9 $
# Total quantity for AVB is 0
# Date :2019-04-18 | Realised Balance: 622116.2
# Bought 189 shares of AVB at 163.7 per share worth 30943.3 $
# Total quantity for AVB is 189
# Date :2019-04-18 | Realised Balance: 591172.8
# Bought 421 shares of WELL at 60.6 per share worth 25504.1 $
# Total quantity for WELL is 0
# Date :2019-04-18 | Realised Balance: 565668.7
# Bought 466 shares of WELL at 60.6 per share worth 28230.2 $
# Total quantity for WELL is 466
# Date :2019-04-18 | Realised Balance: 537438.5
# Bought 411 shares of O at 51.8 per share worth 21293.7 $
# Total quantity for O is 0
# Date :2019-04-23 | Realised Balance: 516144.8
# Bought 498 shares of O at 51.8 per share worth 25801.1 $
# Total quantity for O is 498
# Date :2019-04-23 | Realised Balance: 490343.7
# Sold 193 shares of EOG at 83.5 per share worth 16106.0 $
# Total quantity for EOG is 0
# Date :2019-04-23 | Realised Balance: 506449.7
# Sold 303 shares of EOG at 83.5 per share worth 25285.5 $
# Total quantity for EOG is -303
# Date :2019-04-23 | Realised Balance: 531735.2
# Sold 607 shares of KO at 41.0 per share worth 24884.7 $
# Total quantity for KO is 0
# Date :2019-05-01 | Realised Balance: 556619.9
# Sold 678 shares of KO at 41.0 per share worth 27795.5 $
# Total quantity for KO is -678
# Date :2019-05-01 | Realised Balance: 584415.4
# Bought 277 shares of XOM at 55.5 per share worth 15372.4 $
# Total quantity for XOM is 0
# Date :2019-06-03 | Realised Balance: 569043.0
# Bought 512 shares of XOM at 55.5 per share worth 28413.9 $
# Total quantity for XOM is 512
# Date :2019-06-03 | Realised Balance: 540629.1
# Bought 186 shares of CVX at 92.0 per share worth 17103.9 $
# Total quantity for CVX is 0
# Date :2019-06-03 | Realised Balance: 523525.2
# Bought 284 shares of CVX at 92.0 per share worth 26115.6 $
# Total quantity for CVX is 284
# Date :2019-06-03 | Realised Balance: 497409.6
# Bought 153 shares of PG at 90.6 per share worth 13858.6 $
# Total quantity for PG is 0
# Date :2019-06-03 | Realised Balance: 483551.1
# Bought 266 shares of PG at 90.6 per share worth 24094.0 $
# Total quantity for PG is 266
# Date :2019-06-03 | Realised Balance: 459457.1
# Bought 303 shares of EOG at 64.9 per share worth 19675.7 $
# Total quantity for EOG is 0
# Date :2019-06-03 | Realised Balance: 439781.3
# Bought 338 shares of EOG at 64.9 per share worth 21948.5 $
# Total quantity for EOG is 338
# Date :2019-06-03 | Realised Balance: 417832.8
# Bought 294 shares of MSFT at 117.2 per share worth 34470.3 $
# Total quantity for MSFT is 0
# Date :2019-06-04 | Realised Balance: 383362.5
# Bought 163 shares of MSFT at 117.2 per share worth 19111.1 $
# Total quantity for MSFT is 163
# Date :2019-06-04 | Realised Balance: 364251.5
# Sold 512 shares of XOM at 59.4 per share worth 30418.1 $
# Total quantity for XOM is 0
# Date :2019-06-24 | Realised Balance: 394669.6
# Sold 332 shares of XOM at 59.4 per share worth 19724.2 $
# Total quantity for XOM is -332
# Date :2019-06-24 | Realised Balance: 414393.8
# Sold 338 shares of EOG at 70.9 per share worth 23962.1 $
# Total quantity for EOG is 0
# Date :2019-06-24 | Realised Balance: 438355.9
# Sold 309 shares of EOG at 70.9 per share worth 21906.2 $
# Total quantity for EOG is -309
# Date :2019-06-24 | Realised Balance: 460262.1
# Sold 266 shares of PG at 98.7 per share worth 26264.3 $
# Total quantity for PG is 0
# Date :2019-07-05 | Realised Balance: 486526.4
# Sold 246 shares of PG at 98.7 per share worth 24289.6 $
# Total quantity for PG is -246
# Date :2019-07-05 | Realised Balance: 510815.9
# Sold 402 shares of JPM at 96.9 per share worth 38956.1 $
# Total quantity for JPM is 0
# Date :2019-07-08 | Realised Balance: 549772.0
# Sold 283 shares of JPM at 96.9 per share worth 27424.3 $
# Total quantity for JPM is -283
# Date :2019-07-08 | Realised Balance: 577196.3
# Sold 771 shares of WFC at 41.6 per share worth 32101.7 $
# Total quantity for WFC is 0
# Date :2019-07-29 | Realised Balance: 609298.0
# Sold 731 shares of WFC at 41.6 per share worth 30436.3 $
# Total quantity for WFC is -731
# Date :2019-07-29 | Realised Balance: 639734.3
# Bought 406 shares of AXP at 114.0 per share worth 46272.3 $
# Total quantity for AXP is 0
# Date :2019-08-06 | Realised Balance: 593462.0
# Bought 260 shares of AXP at 114.0 per share worth 29632.5 $
# Total quantity for AXP is 260
# Date :2019-08-06 | Realised Balance: 563829.5
# Bought 283 shares of JPM at 94.3 per share worth 26693.0 $
# Total quantity for JPM is 0
# Date :2019-08-08 | Realised Balance: 537136.5
# Bought 284 shares of JPM at 94.3 per share worth 26787.3 $
# Total quantity for JPM is 284
# Date :2019-08-08 | Realised Balance: 510349.2
# Bought 309 shares of EOG at 63.1 per share worth 19502.1 $
# Total quantity for EOG is 0
# Date :2019-08-08 | Realised Balance: 490847.1
# Bought 388 shares of EOG at 63.1 per share worth 24488.1 $
# Total quantity for EOG is 388
# Date :2019-08-08 | Realised Balance: 466359.0
# Sold 466 shares of WELL at 73.6 per share worth 34300.5 $
# Total quantity for WELL is 0
# Date :2019-08-12 | Realised Balance: 500659.5
# Sold 340 shares of WELL at 73.6 per share worth 25026.1 $
# Total quantity for WELL is -340
# Date :2019-08-12 | Realised Balance: 525685.6
# Bought 332 shares of XOM at 52.6 per share worth 17452.2 $
# Total quantity for XOM is 0
# Date :2019-08-15 | Realised Balance: 508233.3
# Bought 483 shares of XOM at 52.6 per share worth 25389.8 $
# Total quantity for XOM is 483
# Date :2019-08-15 | Realised Balance: 482843.5
# Sold 498 shares of O at 57.2 per share worth 28475.8 $
# Total quantity for O is 0
# Date :2019-09-05 | Realised Balance: 511319.4
# Sold 447 shares of O at 57.2 per share worth 25559.6 $
# Total quantity for O is -447
# Date :2019-09-05 | Realised Balance: 536879.0
# Sold 189 shares of AVB at 180.6 per share worth 34129.0 $
# Total quantity for AVB is 0
# Date :2019-09-05 | Realised Balance: 571007.9
# Sold 158 shares of AVB at 180.6 per share worth 28531.1 $
# Total quantity for AVB is -158
# Date :2019-09-05 | Realised Balance: 599539.0
# Sold 284 shares of CVX at 97.3 per share worth 27619.2 $
# Total quantity for CVX is 0
# Date :2019-09-12 | Realised Balance: 627158.3
# Sold 322 shares of CVX at 97.3 per share worth 31314.7 $
# Total quantity for CVX is -322
# Date :2019-09-12 | Realised Balance: 658473.0
# Sold 388 shares of EOG at 62.6 per share worth 24280.9 $
# Total quantity for EOG is 0
# Date :2019-09-12 | Realised Balance: 682753.9
# Sold 545 shares of EOG at 62.6 per share worth 34105.9 $
# Total quantity for EOG is -545
# Date :2019-09-12 | Realised Balance: 716859.8
# Sold 467 shares of COP at 46.8 per share worth 21849.6 $
# Total quantity for COP is 0
# Date :2019-09-12 | Realised Balance: 738709.3
# Sold 789 shares of COP at 46.8 per share worth 36915.0 $
# Total quantity for COP is -789
# Date :2019-09-12 | Realised Balance: 775624.3
# Sold 284 shares of JPM at 102.3 per share worth 29054.9 $
# Total quantity for JPM is 0
# Date :2019-09-16 | Realised Balance: 804679.3
# Sold 393 shares of JPM at 102.3 per share worth 40206.3 $
# Total quantity for JPM is -393
# Date :2019-09-16 | Realised Balance: 844885.5
# Sold 483 shares of XOM at 57.2 per share worth 27624.9 $
# Total quantity for XOM is 0
# Date :2019-09-17 | Realised Balance: 872510.4
# Sold 762 shares of XOM at 57.2 per share worth 43582.1 $
# Total quantity for XOM is -762
# Date :2019-09-17 | Realised Balance: 916092.4
# Bought 545 shares of EOG at 55.6 per share worth 30322.1 $
# Total quantity for EOG is 0
# Date :2019-10-03 | Realised Balance: 885770.4
# Bought 796 shares of EOG at 55.6 per share worth 44286.9 $
# Total quantity for EOG is 796
# Date :2019-10-03 | Realised Balance: 841483.5
# Bought 393 shares of JPM at 97.5 per share worth 38307.4 $
# Total quantity for JPM is 0
# Date :2019-10-09 | Realised Balance: 803176.1
# Bought 411 shares of JPM at 97.5 per share worth 40061.9 $
# Total quantity for JPM is 411
# Date :2019-10-09 | Realised Balance: 763114.2
# Sold 163 shares of MSFT at 136.4 per share worth 22237.1 $
# Total quantity for MSFT is 0
# Date :2019-10-29 | Realised Balance: 785351.3
# Sold 287 shares of MSFT at 136.4 per share worth 39153.7 $
# Total quantity for MSFT is -287
# Date :2019-10-29 | Realised Balance: 824505.0
# Bought 158 shares of AVB at 179.8 per share worth 28409.8 $
# Total quantity for AVB is 0
# Date :2019-11-06 | Realised Balance: 796095.2
# Bought 221 shares of AVB at 179.8 per share worth 39737.8 $
# Total quantity for AVB is 221
# Date :2019-11-06 | Realised Balance: 756357.3
# Bought 447 shares of O at 58.7 per share worth 26241.0 $
# Total quantity for O is 0
# Date :2019-11-11 | Realised Balance: 730116.4
# Bought 621 shares of O at 58.7 per share worth 36455.6 $
# Total quantity for O is 621
# Date :2019-11-11 | Realised Balance: 693660.8
# Bought 340 shares of WELL at 70.2 per share worth 23874.6 $
# Total quantity for WELL is 0
# Date :2019-11-11 | Realised Balance: 669786.2
# Bought 476 shares of WELL at 70.2 per share worth 33424.4 $
# Total quantity for WELL is 476
# Date :2019-11-11 | Realised Balance: 636361.9
# Sold 223 shares of GS at 197.2 per share worth 43982.8 $
# Total quantity for GS is 0
# Date :2019-12-09 | Realised Balance: 680344.7
# Sold 172 shares of GS at 197.2 per share worth 33924.0 $
# Total quantity for GS is -172
# Date :2019-12-09 | Realised Balance: 714268.7
# Sold 411 shares of JPM at 116.3 per share worth 47808.9 $
# Total quantity for JPM is 0
# Date :2019-12-09 | Realised Balance: 762077.6
# Sold 327 shares of JPM at 116.3 per share worth 38037.8 $
# Total quantity for JPM is -327
# Date :2019-12-09 | Realised Balance: 800115.4
# Sold 796 shares of EOG at 59.5 per share worth 47391.0 $
# Total quantity for EOG is 0
# Date :2019-12-13 | Realised Balance: 847506.4
# Sold 711 shares of EOG at 59.5 per share worth 42330.4 $
# Total quantity for EOG is -711
# Date :2019-12-13 | Realised Balance: 889836.8
# Sold 260 shares of AXP at 115.5 per share worth 30020.1 $
# Total quantity for AXP is 0
# Date :2019-12-16 | Realised Balance: 919857.0
# Sold 398 shares of AXP at 115.5 per share worth 45953.9 $
# Total quantity for AXP is -398
# Date :2019-12-16 | Realised Balance: 965810.9
# Closed open trades for 287 shares of MSFT at 151.0 per share worth 43346.8 $
# Closed open trades for 453 shares of AAPL at 70.7 per share worth 32042.3 $
# Closed open trades for 172 shares of GS at 204.3 per share worth 35146.0 $
# Closed open trades for 731 shares of WFC at 47.2 per share worth 34497.5 $
# Closed open trades for 762 shares of XOM at 55.0 per share worth 41883.3 $
# Closed open trades for 322 shares of CVX at 96.9 per share worth 31214.4 $
# Closed open trades for 87 shares of PSA at 172.5 per share worth 15006.9 $
# Closed open trades for 621 shares of O at 56.3 per share worth 34981.7 $
# Closed open trades for 246 shares of PG at 110.0 per share worth 27064.4 $
# Closed open trades for 678 shares of KO at 47.7 per share worth 32336.2 $
# Closed open trades for 407 shares of AMZN at 92.3 per share worth 37584.2 $
# Closed open trades for 237 shares of IBM at 101.4 per share worth 24035.0 $
# Closed open trades for 398 shares of AXP at 116.0 per share worth 46184.2 $
# Closed open trades for 327 shares of JPM at 120.0 per share worth 39232.0 $
# Closed open trades for 711 shares of EOG at 65.0 per share worth 46199.5 $
# Closed open trades for 789 shares of COP at 54.1 per share worth 42646.3 $
# Closed open trades for 221 shares of AVB at 177.1 per share worth 39148.6 $
# Closed open trades for 476 shares of WELL at 69.2 per share worth 32924.5 $
# Closed open trades for 147 shares of PEP at 119.5 per share worth 17566.6 $
# Closed open trades for 194 shares of COST at 271.2 per share worth 52621.1 $
# Closed open trades for 0 shares of XLK at 87.5 per share worth 0.0 $
# Closed open trades for 0 shares of XLF at 27.9 per share worth 0.0 $
# Closed open trades for 0 shares of XLE at 48.3 per share worth 0.0 $
# Closed open trades for 0 shares of IYR at 81.5 per share worth 0.0 $
# Closed open trades for 0 shares of XLP at 55.5 per share worth 0.0 $
# Closed open trades for 0 shares of XLY at 120.2 per share worth 0.0 $
# ==================================================
# Performance Metrics
# The total capital at end of strategy: 552342.6
# The annual regular returns: 3.49 %
# The annual regular std deviation: 6.51 %
# The annual Sharpe Ratio: 0.54
# The returns on investment from 2017-01-01 to 2019-12-31 by this strategy is 10.5 %
# The maximum drawdown: 7.15 %
# The maximum drawdown period: 140.00 days
# The annual Sortino Ratio: 0.84
# The total trades taken by the strategy: 310
# ==================================================
