# %% [markdown]
# Adding stored data to store the trades for calculation of results

# %%
# Changes from 8:
# Almost similar to notebook 8, but for multiple instruments
# The adding of dictionaries, so that the data for all stocks can be stored
# Added one more func to stop trading when total capital  < 0. Previous model doesnt takes that into account.

# %%
# Install all important libraries
# !pip install yfinance
# !pip install ta
# Out:
# Requirement already satisfied: yfinance in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.26.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.2.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.12.0)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ta in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from ta) (1.26.0)
# Requirement already satisfied: pandas in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from ta) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas->ta) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from pandas->ta) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ryanl\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# NSE list Dont run
list = ["BRITANNIA.NS", "ULTRACEMCO.NS","KOTAKBANK.NS", "HEROMOTOCO.NS" , "BAJAJ-AUTO.NS", "GRASIM.NS","ONGC.NS", "TITAN.NS" , "SHREECEM.NS" ,\
        "NESTLEIND.NS", "GAIL.NS", "CIPLA.NS", "BHARTIARTL.NS" ,"NTPC.NS", "TATASTEEL.NS", "COALINDIA.NS", "BAJFINANCE.NS", "ICICIBANK.NS",\
       "BAJAJFINSV.NS", "WIPRO.NS", "HINDALCO.NS" , "HDFCLIFE.NS", "MARUTI.NS", "RELIANCE.NS", "TCS.NS", "LT.NS", "INDUSINDBK.NS", "ITC.NS" , "TECHM.NS"]

# %%
# SGX list Dont run
list = ["C52.SI", "T39.SI", "S68.SI", "G13.SI", "V03.SI" , "U11.SI", "C07.SI" , "D05.SI", "Z74.SI",\
        "D01.SI", "O39.SI", "S63.SI", "A17U.SI" , "BN4.SI","BS6.SI", "M44U.SI", "C31.SI", "H78.SI", \
        "Y92.SI", "C38U.SI", "U14.SI", "N2IU.SI" , "F34.SI" , "C09.SI" , "J36.SI", "S58.SI" , "C6L.SI", "J37.SI", "U96.SI" ,"1810.HK"]

# %%
# import all libraries

from ta.utils import dropna
from ta.volatility import BollingerBands
from ta.trend import ADXIndicator
from ta.volatility import AverageTrueRange
from ta.trend import SMAIndicator
from ta.momentum import RSIIndicator
from ta.volume import VolumeWeightedAveragePrice

import math
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# For event based backtesting, an imporatant concept is a bar.
# A bar is unit of data or information. A bar represents an event.
# Event based Backtesting will be based on new bars coming at not on full dataset.

# First we will build a commonclass,
# this will be utilised for all the common purposes like preparing data, plotting results, placing orders etc

# %%
class Common_Class():

  def __init__(self, symbol, start, end, interval, capital, transaction_cost, verbose=True):
        # Initialize variables
        self.all_data = {}
        self.position = {}
        self.quantity = {}
        for stock in symbol:
            self.quantity[stock] = 0
            self.position[stock] = 0

        self.symbol = symbol
        self.start = start
        self.end = end
        self.interval = interval
        self.initial_capital = capital
        self.capital = capital
        self.transaction_cost = transaction_cost
        self.trades = 0
        self.verbose = verbose
        self.stored_data = pd.DataFrame(columns=['trade', 'date', 'position', 'price', 'symbol', 'quantity', 'capital'])
        self.prepare_data()


  def prepare_data(self):
        for i in self.symbol:
            stock_data = yf.Ticker(i)
            hist_stock = stock_data.history(start=self.start, end=self.end, interval=self.interval)
            bt_data = pd.DataFrame()
            bt_data["Close_Price"] = hist_stock["Close"]
            bt_data["Return"] = np.log(bt_data["Close_Price"] / bt_data["Close_Price"].shift(1))
            bt_data = bt_data.dropna()
            self.all_data[i] = bt_data

  def close_graph(self, stock):
    i = str(stock)
    plt.figure(figsize=(15, 5))
    plt.plot(self.all_data[i]["Close_Price"] ,color='black', label='Price', linestyle='dashed')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.title("Close Prices of {}".format(i))
    plt.legend()
    plt.grid()
    plt.show()

  def return_date_price(self, bar, stock):
        i = str(stock)
        date = str(self.all_data[i].index[bar])[:10]
        price = self.all_data[i].Close_Price.iloc[bar]
        return date, price

  def realised_balance(self, bar):
    #Returns you the realised capital in your account at a given time period / bar
    date, price = self.return_date_price(bar, self.symbol[0]) # only concerned with date so any stock will do
    print("Date :{} | Realised Balance: {:0.1f}".format(date,self.capital))

  def unrealised_balance(self, bar):
    #Returns you the unrealised capital (trades in progress) in your account at a given time period / bar
    ub = 0
    for stock in self.symbol:
      date, price = self.return_date_price(bar, stock)
      ub =  ub + self.quantity['{}'.format(stock)] *price
    #print("Date :{} | Unrealised Balance: {:0.1f}".format(date,ub))

  def total_balance(self, bar):
        ub = 0
        for stock in self.symbol:
            date, price = self.return_date_price(bar, stock)
            ub += self.quantity[stock] * price
        tb = ub + self.capital
        return tb

  def store_results(self, trade, date, position, price, symbol, quantity, capital):
        trade_detail = pd.DataFrame({
            'trade': pd.Series(trade),
            'date': pd.Series(date),
            'position': pd.Series(position),
            'price': pd.Series(price),
            'symbol': pd.Series(symbol),
            'quantity': pd.Series(quantity),
            'capital': pd.Series(capital)
        })
        self.stored_data = pd.concat([self.stored_data, trade_detail])

  def performance_plots(self):

    Final_result_data = self.Final_result_data #saving time to write self everywhere
    interval = str(self.interval)
    f,ax = plt.subplots(2,3,figsize=(20,10))

    #plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)

    #f.tight_layout(h_pad=5, w_pad=2)

    #plot 1: Close Price os stock
    plt.subplot(2, 3, 1)
    for stock in self.symbol:
      plt.plot(Final_result_data['Returns_{}'.format(stock)].cumsum(), label='{}'.format(stock), linestyle='dashed')
    plt.title("Cum Log returns of included stocks")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 2: Histogram of dtrstegy returns
    plt.subplot(2, 3, 2)
    plt.hist(Final_result_data['capital_log_returns'], bins = 35, label='Strategy Returns', linestyle='dashed')
    plt.title("Histogram of Strategy returns")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 3: Strategy vs Instrument
    plt.subplot(2, 3, 3)
    plt.plot(Final_result_data['Total_Stock_Returns_cum_sum'],color='red', label='Equal weighted stock Returns', linestyle='dashed')
    plt.plot(Final_result_data['capital_returns_log_cum_sum'].dropna(), label ='Strategy Returns')
    plt.title("Strategy Vs Stock Cum Return Curve")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 4: Drawdown
    plt.subplot(2, 3, 4)
    plt.plot(Final_result_data["capital_returns_log_cum_sum"].dropna(), label='Cum log returns')
    plt.plot(Final_result_data["Cum_Max"].dropna(), label =  'Max Drawdown')
    plt.title("Drawdown")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    #plot 5: Equity Curve
    plt.subplot(2, 3,  5)
    plt.plot(Final_result_data["capital"].dropna(), label =  'Equity $')
    plt.title("Equity Curve")
    plt.xlabel(interval)
    plt.legend()
    plt.grid()

    plt.suptitle("Performance Plots")
    f.delaxes(ax[1,2]) # to delete the last subplot

    plt.show()

  def performance(self):
        df = pd.DataFrame()
        df['capital'] = self.stored_data.groupby('date').agg({'capital': 'mean'})

        trade_start_date = df.index[0]
        trade_end_date = df.index[-1]

        for stock in self.symbol:
            A = self.all_data[stock][trade_start_date:trade_end_date]['Return'].tolist()
            df[f'Returns_{stock}'] = A

        c = df.columns
        df['Total_Stock_Returns'] = df.loc[:, c[-len(self.symbol):]].mean(axis=1)
        df['Total_Stock_Returns_cum_sum'] = df['Total_Stock_Returns'].cumsum()
        df.index = range(df.shape[0])

        df['capital_after_settlement'] = df['capital'].shift(-1)

        df['capital_regular_returns'] = df['capital_after_settlement'] / df['capital'] - 1
        df['capital_log_returns'] = np.log(df['capital_after_settlement'] / df['capital'])
        df['capital_returns_log_cum_sum'] = df['capital_log_returns'].cumsum()

        df['Cum_Max'] = df['capital_returns_log_cum_sum'].cummax()
        df['drawdown'] = df['Cum_Max'] - df['capital_returns_log_cum_sum']

        df.dropna(inplace=True)

        Final_result_data = df

        # Calculate performance metrics
        daily_log_mean_ret = Final_result_data['capital_log_returns'].mean()
        annual_log_ret = 252 * daily_log_mean_ret
        annual_regular_return = (np.exp(annual_log_ret) - 1) * 100

        daily_regular_std = (np.exp(Final_result_data['capital_log_returns']) - 1).std()
        annual_regular_std = daily_regular_std * np.sqrt(252) * 100

        SR = annual_regular_return / annual_regular_std

        returns = (self.capital - self.initial_capital) / self.initial_capital * 100

        Drawdown = Final_result_data['drawdown'].max() * 100

        zero_periods = Final_result_data[Final_result_data['drawdown'] == 0]
        delta_values = (zero_periods.index[1:] - zero_periods.index[:-1])

        only_neg_log_returns = Final_result_data[Final_result_data['capital_log_returns'] < 0]['capital_log_returns']
        only_neg_regular_returns = np.exp(only_neg_log_returns) - 1

        daily_std_dev_for_sortino = only_neg_regular_returns.std()
        annual_std_dev_for_sortino = daily_std_dev_for_sortino * np.sqrt(252) * 100

        sortino = annual_regular_return / annual_std_dev_for_sortino

        # Store metrics for hyperparameter tuning
        self.metrics = {
            'annual_return': annual_regular_return,
            'annual_std': annual_regular_std,
            'sharpe_ratio': SR,
            'sortino_ratio': sortino,
            'max_drawdown': Drawdown,
            'total_trades': self.trades,
            'returns': returns,
        }

        # Print performance metrics if verbose
        if self.verbose:
            print("=" * 50)
            print("Performance Metrics")
            print(f"The total capital at end of strategy: {self.capital:0.1f}")
            print(f"The annual regular returns: {annual_regular_return:0.2f} %")
            print(f"The annual regular std deviation: {annual_regular_std:0.2f} %")
            print(f"The annual Sharpe Ratio: {SR:0.2f}")
            print(f"The returns on investment from {self.start} to {self.end} by this strategy is {returns:0.1f} %")
            print(f"The maximum drawdown: {Drawdown:.2f} %")
            print(f"The maximum drawdown period: {delta_values.max() if not delta_values.empty else 0:.2f} days")
            print(f"The annual Sortino Ratio: {sortino:0.2f}")
            print(f"The total trades taken by the strategy: {self.trades}")
            print("=" * 50)

        self.Final_result_data = Final_result_data

  def buy_order(self,bar,stock,quantity=None, dollar =None ):
    date, price = self.return_date_price(bar,stock)
    if quantity == None:
      quantity = int(dollar/price)
    self.capital = self.capital - ((quantity * price)*(1 + self.transaction_cost)) # capital will be lost in buying
    self.quantity['{}'.format(stock)] = self.quantity['{}'.format(stock)] + quantity
    self.trades = self.trades + 1
    self.position['{}'.format(stock)] = 1
    tb = self.total_balance(bar)
    #self.quantity['{}'.format(stock)]*price + self.capital # this is just for one stock, however, I need for all the stocks
    self.store_results(self.trades, date, self.position['{}'.format(stock)], price, stock, quantity, tb)


    if self.verbose:
      print("Bought {} shares of {} at {:0.1f} per share worth {:0.1f} $".format(quantity,stock, price, quantity * price))
      print('Total quantity for {} is {}'.format(stock,self.quantity['{}'.format(stock)]))
      self.realised_balance(bar)
      #self.unrealised_balance(bar)
      #self.total_balance(bar)


  def sell_order(self,bar,stock, quantity=None, dollar=None ):
    date, price = self.return_date_price(bar, stock)
    if quantity == None:
      quantity = int(dollar/price)
    self.capital = self.capital + ((quantity * price)*(1 - self.transaction_cost)) # capital will be added after selling
    self.quantity['{}'.format(stock)] = self.quantity['{}'.format(stock)] - quantity
    self.trades = self.trades + 1
    self.position['{}'.format(stock)] = -1
    tb = self.total_balance(bar) # to store the total balance due to all the stocks at the end of the day, so that I get 1 value at the EOD
    self.store_results(self.trades, date, self.position['{}'.format(stock)], price, stock, quantity, tb)


    if self.verbose:
      print("Sold {} shares of {} at {:0.1f} per share worth {:0.1f} $".format(quantity,stock, price, quantity * price))
      print('Total quantity for {} is {}'.format(stock,self.quantity['{}'.format(stock)]))
      self.realised_balance(bar)
      #self.unrealised_balance(bar)
      #self.total_balance(bar)

  def last_trade(self, bar):# this needs to be check for all open positions of all stocks

    for stock in self.symbol:
      date, price = self.return_date_price(bar, stock)
      last_quantity = self.quantity['{}'.format(stock)]
      self.capital = self.capital + last_quantity * price
      self.quantity['{}'.format(stock)] = 0 # as no more quantity now. all will be settled
      self.trades = self.trades +1
      if self.position['{}'.format(stock)] == -1: # if closing out a short position
        last_quantity = - last_quantity # to keep a positve nymber in records. Note, self.quantity is always maintianing a +/- sign.
        self.position['{}'.format(stock)] = 1 # to record we are buying to close out
      else:
        last_quantity =  last_quantity # to keep a positve nymber in records
        self.position['{}'.format(stock)] = -1 # to record we are selling to close out
      #self.position = 0
      tb = self.total_balance(bar)
      self.store_results(self.trades, date, self.position['{}'.format(stock)], price, stock, last_quantity, tb)

      if self.verbose:
        print("Closed open trades for {} shares of {} at {:0.1f} per share worth {:0.1f} $".format(last_quantity,stock, price, last_quantity * price))
        #print("--------------Final Balance-----------")
        #self.total_balance(bar)
        #returns = (self.capital - self.initial_capital) /self.initial_capital *100
        #print("------------------------------")
        #print("The total capital at end of strategy: {:0.1f}".format(self.capital))
        #print("The strategy returns on investment are {:0.1f} %".format(returns))
        #print("Total trades by startegy are {:0.1f}".format(self.trades))

    #print("=" *50)
    #print("--------------Final Balance-----------")
    #tb = self.total_balance(bar)
    #print("Total balan from tb is ", tb)
    #print('self.capital is ', self.capital)
    #returns = (self.capital - self.initial_capital) /self.initial_capital *100
    #print("The total capital at end of strategy: {:0.1f}".format(self.capital))
    #print("The strategy returns on investment are {:0.1f} %".format(returns))
    #print("Total trades by startegy are {:0.1f}".format(self.trades))
    #print("=" *50)

# %%
class MA_Strategy(Common_Class):

  def go_long(self, bar, stock, quantity = None, dollar = None): # either previously in position or fresh position
    if self.position['{}'.format(stock)] == -1:
      self.position['{}'.format(stock)] = 0
      self.buy_order(bar,stock, quantity = -self.quantity['{}'.format(stock)]) #to clear previous short position and therefore negative quantity.(already in position, thats why negative)
    if quantity:
      self.buy_order (bar, stock, quantity = quantity) # to create new fresh order
    elif dollar:
      if dollar == 'all':
        dollar = self.capital
      else:
        dollar = self.capital/len(self.symbol)
      self.buy_order(bar, stock, dollar = dollar)


  def go_short(self, bar, stock, quantity = None, dollar = None):
    if self.position['{}'.format(stock)] == 1:
      self.position['{}'.format(stock)] = 0
      self.sell_order(bar,stock, quantity = self.quantity['{}'.format(stock)]) #to clear previous long vposition
    if quantity:
      self.sell_order (bar, stock, quantity = quantity) # to create new fresh order
    elif dollar:
      if dollar == 'all':
        dollar = self.capital
      else:
        dollar = self.capital/len(self.symbol)
      self.sell_order(bar, stock, dollar = dollar)

  def run_strategy(self, STMA_window, LTMA_window): # add the parameters according to the strategy
    self.stop = False
    self.trades = 0
    self.capital = self.initial_capital

    #Preparing data with LTMA and STMA so that can check crossovers. Also initialising with 0 quantity and 0 position

    for stock in self.symbol:
      self.quantity['{}'.format(stock)] = 0
      self.position['{}'.format(stock)] = 0

      indicator_1 = SMAIndicator(close = self.all_data['{}'.format(stock)]["Close_Price"], window = STMA_window, fillna= False)
      STMA = indicator_1.sma_indicator()

      indicator_2 = SMAIndicator(close = self.all_data['{}'.format(stock)]["Close_Price"], window = LTMA_window, fillna= False)
      LTMA = indicator_2.sma_indicator()

      self.all_data['{}'.format(stock)]['STMA_{}'.format(stock)] = STMA
      self.all_data['{}'.format(stock)]['LTMA_{}'.format(stock)] = LTMA

    for bar in range(LTMA_window, len(self.all_data['{}'.format(self.symbol[0])])): # from the available data bar to the last data bar
      #Making a func so that no trade if balance goes below 0

      tb = self.total_balance(bar)
      if tb< 0:
        print("negative capital")
        self.last_trade(bar)
        self.stop = True
        break

      for stock in self.symbol:
        date, price = self.return_date_price(bar, stock)

        if self.position['{}'.format(stock)] in [0,-1]: # checking no position or short position
          if self.all_data['{}'.format(stock)]['STMA_{}'.format(stock)].iloc[bar] > self.all_data['{}'.format(stock)]['LTMA_{}'.format(stock)].iloc[bar]:
             self.go_long(bar,stock, dollar = self.capital/len(self.symbol)) # go with equal money # Make sure to enter less than initila capital
             #print("--------")
             continue # as I am storing data for SR calculations. Dont wnat duplication

        if self.position['{}'.format(stock)] in [0,1]: # checking no position or long position
          if self.all_data['{}'.format(stock)]['STMA_{}'.format(stock)].iloc[bar] < self.all_data['{}'.format(stock)]['LTMA_{}'.format(stock)].iloc[bar]:
            self.go_short(bar,stock, dollar =self.capital/len(self.symbol)) # go with equal money
            #print("--------")
            continue

        #-----Storing all the values for calculating Sharpe-----
        store_quantity = abs(self.quantity['{}'.format(stock)]) # so that I want just the positive numbers in my performance table. I will calculate +/- based on position sign
        tb = self.total_balance(bar)
        self.store_results(0, date, self.position['{}'.format(stock)], price, stock, store_quantity, tb)  # I have used continue in previous "if conditions", So if they didnt execute meaning no trade conditions that day ; trade = 0

    if self.stop == False: # to make sure not to run this func 2 times when early exit due to negative balance
      self.last_trade(bar)  # amke sure the crossover happens, give more time

if __name__ == "__main__":
    stocks = ['MSFT', 'AAPL', 'GS', 'WFC', 'XOM', 'CVX', 'PSA', 'O', 'PG', 'KO', 'AMZN', 'IBM', 'AXP', 'JPM','EOG','COP', 'AVB', 'WELL','PEP','COST']
    A = MA_Strategy(stocks, "2020-01-01", "2020-06-01","1d", 10000, 0.00, False)
    A.run_strategy(10,40)
    A.performance()
    A.performance_plots()

  #UnboundLocalError: local variable 'bar' referenced before assignment
  # If duration of test or difference between start date aand end date is less than MA
# Out:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_7444\1730464758.py:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.stored_data = pd.concat([self.stored_data, trade_detail])
# ==================================================
# Performance Metrics
# The total capital at end of strategy: 12338.0
# The annual regular returns: 138.20 %
# The annual regular std deviation: 56.56 %
# The annual Sharpe Ratio: 2.44
# The returns on investment from 2020-01-01 to 2020-06-01 by this strategy is 23.4 %
# The maximum drawdown: 18.46 %
# The maximum drawdown period: 2.00 days
# The annual Sortino Ratio: 4.51
# The total trades taken by the strategy: 108
# ==================================================

# %% [markdown]
# The Bollinger Bands strategy with sector ETF confirmation trades a diversified portfolio of stocks using Bollinger Bands to generate buy and sell signals, but only executes trades when these signals are confirmed by the corresponding sector ETFs, aligning individual stock movements with broader sector trends. By optimizing the Bollinger Bands parameters (window size and standard deviation multiplier) through hyperparameter tuning on historical data, the strategy aims to enhance trade accuracy and achieve better risk-adjusted returns during the testing period.

# %%
from ta.volatility import BollingerBands
from ta.momentum import RSIIndicator

class BollingerBandStrategy(Common_Class):

    def __init__(self, symbol, start, end, interval, capital, transaction_cost, verbose=True, window=20, window_dev=2, rsi_window=14, rsi_buy=40, rsi_sell=60):
        super().__init__(symbol, start, end, interval, capital, transaction_cost, verbose)
        self.window = window if window else 20
        self.window_dev = window_dev if window_dev else 2
        self.rsi_window = rsi_window if rsi_window else 14
        self.rsi_buy = rsi_buy if rsi_buy else 40
        self.rsi_sell = rsi_sell if rsi_sell else 60

        # Sector mapping
        self.sector_mapping = {
            'MSFT': 'Technology',
            'AAPL': 'Technology',
            'GS': 'Financials',
            'WFC': 'Financials',
            'XOM': 'Energy',
            'CVX': 'Energy',
            'PSA': 'Real Estate',
            'O': 'Real Estate',
            'PG': 'Consumer Staples',
            'KO': 'Consumer Staples',
            'AMZN': 'Consumer Discretionary',
            'IBM': 'Technology',
            'AXP': 'Financials',
            'JPM': 'Financials',
            'EOG': 'Energy',
            'COP': 'Energy',
            'AVB': 'Real Estate',
            'WELL': 'Real Estate',
            'PEP': 'Consumer Staples',
            'COST': 'Consumer Staples'
        }

        self.sector_etfs = {
            'Technology': 'XLK',
            'Financials': 'XLF',
            'Energy': 'XLE',
            'Real Estate': 'IYR',
            'Consumer Staples': 'XLP',
            'Consumer Discretionary': 'XLY'
        }

        self.stocks = [s for s in self.symbol if s not in self.sector_etfs.values()]


    def go_long(self, bar, stock, quantity=None, dollar=None):
        if self.position[stock] == -1:
            self.position[stock] = 0
            self.buy_order(bar, stock, quantity=-self.quantity[stock])
        if quantity:
            self.buy_order(bar, stock, quantity=quantity)
        elif dollar:
            if dollar == 'all':
                dollar = self.capital
            else:
                dollar = self.capital / len(self.stocks)
            self.buy_order(bar, stock, dollar=dollar)

    def go_short(self, bar, stock, quantity=None, dollar=None):
        if self.position[stock] == 1:
            self.position[stock] = 0
            self.sell_order(bar, stock, quantity=self.quantity[stock])
        if quantity:
            self.sell_order(bar, stock, quantity=quantity)
        elif dollar:
            if dollar == 'all':
                dollar = self.capital
            else:
                dollar = self.capital / len(self.stocks)
            self.sell_order(bar, stock, dollar=dollar)

    def run_strategy(self):
        self.stop = False
        self.trades = 0
        self.capital = self.initial_capital

        # Compute Bollinger Bands for stocks
        for stock in self.stocks:
            indicator_bb = BollingerBands(
                close=self.all_data[stock]["Close_Price"],
                window=self.window,
                window_dev=self.window_dev
            )
            self.all_data[stock]['bb_middle_band'] = indicator_bb.bollinger_mavg()
            self.all_data[stock]['bb_upper_band'] = indicator_bb.bollinger_hband()
            self.all_data[stock]['bb_lower_band'] = indicator_bb.bollinger_lband()

            # RSI
            indicator_rsi = RSIIndicator(
                close=self.all_data[stock]["Close_Price"],
                window=self.rsi_window
            )
            self.all_data[stock]['rsi'] = indicator_rsi.rsi()

        # Compute Bollinger Bands for sector ETFs
        for etf in self.sector_etfs.values():
            indicator_bb = BollingerBands(
                close=self.all_data[etf]["Close_Price"],
                window=self.window,
                window_dev=self.window_dev
            )
            self.all_data[etf]['bb_middle_band'] = indicator_bb.bollinger_mavg()
            self.all_data[etf]['bb_upper_band'] = indicator_bb.bollinger_hband()
            self.all_data[etf]['bb_lower_band'] = indicator_bb.bollinger_lband()
        
        start_bar = max(self.window, self.rsi_window)

        # Run the strategy
        for bar in range(start_bar, len(self.all_data[self.stocks[0]])):
            tb = self.total_balance(bar)
            if tb < 0:
                print("Negative capital")
                self.last_trade(bar)
                self.stop = True
                break

            for stock in self.stocks:
                date, price = self.return_date_price(bar, stock)
                sector = self.sector_mapping[stock]
                sector_etf = self.sector_etfs[sector]

                # Stock signals
                price_stock_current = self.all_data[stock]['Close_Price'].iloc[bar]
                price_stock_previous = self.all_data[stock]['Close_Price'].iloc[bar - 1]
                lower_band_stock_current = self.all_data[stock]['bb_lower_band'].iloc[bar]
                lower_band_stock_previous = self.all_data[stock]['bb_lower_band'].iloc[bar - 1]
                upper_band_stock_current = self.all_data[stock]['bb_upper_band'].iloc[bar]
                upper_band_stock_previous = self.all_data[stock]['bb_upper_band'].iloc[bar - 1]
                rsi_stock = self.all_data[stock]['rsi'].iloc[bar]

                # Initialize signal
                signal_stock = 'hold'

                # Determine Bollinger Bands signal
                if (price_stock_previous < lower_band_stock_previous) and (price_stock_current > lower_band_stock_current):
                    bb_signal_stock = 'buy'
                elif (price_stock_previous > upper_band_stock_previous) and (price_stock_current < upper_band_stock_current):
                    bb_signal_stock = 'sell'
                else:
                    bb_signal_stock = 'hold'

                # Incorporate RSI into signal
                if bb_signal_stock == 'buy' and rsi_stock < rsi_buy:
                    signal_stock = 'buy'
                elif bb_signal_stock == 'sell' and rsi_stock > rsi_sell:
                    signal_stock = 'sell'

                # Sector ETF signals (same as before)
                price_etf_current = self.all_data[sector_etf]['Close_Price'].iloc[bar]
                price_etf_previous = self.all_data[sector_etf]['Close_Price'].iloc[bar - 1]
                lower_band_etf_current = self.all_data[sector_etf]['bb_lower_band'].iloc[bar]
                lower_band_etf_previous = self.all_data[sector_etf]['bb_lower_band'].iloc[bar - 1]
                upper_band_etf_current = self.all_data[sector_etf]['bb_upper_band'].iloc[bar]
                upper_band_etf_previous = self.all_data[sector_etf]['bb_upper_band'].iloc[bar - 1]

                if (price_etf_previous < lower_band_etf_previous) and (price_etf_current > lower_band_etf_current):
                    signal_etf = 'buy'
                elif (price_etf_previous > upper_band_etf_previous) and (price_etf_current < upper_band_etf_current):
                    signal_etf = 'sell'
                else:
                    signal_etf = 'hold'

                # Proceed if signals agree
                if signal_stock == signal_etf and signal_stock != 'hold':
                    if signal_stock == 'buy':
                        if self.position[stock] <= 0:
                            self.go_long(bar, stock, dollar=self.capital / len(self.stocks))
                    elif signal_stock == 'sell':
                        if self.position[stock] >= 0:
                            self.go_short(bar, stock, dollar=self.capital / len(self.stocks))
                    trade = 1
                else:
                    trade = 0

                # Store results
                store_quantity = abs(self.quantity[stock])
                tb = self.total_balance(bar)
                self.store_results(trade, date, self.position[stock], price, stock, store_quantity, tb)

        if not self.stop:
            self.last_trade(bar)


def hyperparameter_tuning(symbols, initial_capital, transaction_cost, verbose, start_date, end_date, window_range, window_dev_range):
    best_sharpe = float('-inf')
    best_params = None
    tuning_results = []

    for window in window_range:
        for window_dev in window_dev_range:
            print(f"Testing window={window}, window_dev={window_dev}")
            strategy = BollingerBandStrategy(
                symbols,
                start_date,
                end_date,
                "1d",
                initial_capital,
                transaction_cost,
                verbose,
                window=window,
                window_dev=window_dev
            )
            strategy.run_strategy()
            strategy.performance()
            metrics = strategy.metrics
            metrics['window'] = window
            metrics['window_dev'] = window_dev
            tuning_results.append(metrics)
            if metrics['sharpe_ratio'] > best_sharpe:
                best_sharpe = metrics['sharpe_ratio']
                best_params = (window, window_dev)

    return best_params, tuning_results

if __name__ == "__main__":
    # Define stocks and sector ETFs
    stocks = ['MSFT', 'AAPL', 'GS', 'WFC', 'XOM', 'CVX', 'PSA', 'O', 'PG', 'KO',
              'AMZN', 'IBM', 'AXP', 'JPM', 'EOG', 'COP', 'AVB', 'WELL', 'PEP', 'COST']
    sector_etfs = {
        'Technology': 'XLK',
        'Financials': 'XLF',
        'Energy': 'XLE',
        'Real Estate': 'IYR',
        'Consumer Staples': 'XLP',
        'Consumer Discretionary': 'XLY'
    }
    symbols = stocks + list(sector_etfs.values())
    initial_capital = 500000
    transaction_cost = 0.00
    verbose = True

    # # Training period
    # train_start_date = "2010-01-01"
    # train_end_date = "2016-12-31"

    # # Hyperparameter ranges
    # window_range = [10, 20, 30, 40, 50]
    # window_dev_range = [1, 1.5, 2, 2.5, 3]

    # # Perform hyperparameter tuning
    # best_params, tuning_results = hyperparameter_tuning(
    #     symbols,
    #     initial_capital,
    #     transaction_cost,
    #     verbose,
    #     train_start_date,
    #     train_end_date,
    #     window_range,
    #     window_dev_range
    # )

    # print(f"Best parameters: window={best_params[0]}, window_dev={best_params[1]}")

    # if best_params:
    #     window = best_params[0]
    #     window_dev = best_params[1]
    # else:
    window = 20
    window_dev = 2
    rsi_window = 14
    rsi_buy = 40
    rsi_sell = 60

    # Testing period
    test_start_date = "2017-01-01"
    test_end_date = "2019-12-31"

    # Run strategy with best parameters on testing period
    strategy = BollingerBandStrategy(
        symbols,
        test_start_date,
        test_end_date,
        "1d",
        initial_capital,
        transaction_cost,
        verbose,
        window=window,
        window_dev=window_dev,
        rsi_window=rsi_window,
        rsi_buy=rsi_buy,
        rsi_sell=rsi_sell
    )
    strategy.run_strategy()
    strategy.performance()
    strategy.performance_plots()
# Out:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_21052\3884642560.py:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.stored_data = pd.concat([self.stored_data, trade_detail])
# Bought 309 shares of CVX at 80.8 per share worth 24957.1 $
# Total quantity for CVX is 309
# Date :2017-02-02 | Realised Balance: 475042.9
# Bought 314 shares of EOG at 75.6 per share worth 23740.3 $
# Total quantity for EOG is 314
# Date :2017-02-08 | Realised Balance: 451302.7
# Sold 106 shares of GS at 211.7 per share worth 22440.3 $
# Total quantity for GS is -106
# Date :2017-02-16 | Realised Balance: 473743.0
# Sold 506 shares of WFC at 46.8 per share worth 23679.7 $
# Total quantity for WFC is -506
# Date :2017-02-16 | Realised Balance: 497422.7
# Sold 348 shares of AXP at 71.5 per share worth 24864.8 $
# Total quantity for AXP is -348
# Date :2017-02-16 | Realised Balance: 522287.4
# Sold 173 shares of COST at 150.8 per share worth 26082.8 $
# Total quantity for COST is -173
# Date :2017-02-16 | Realised Balance: 548370.2
# Sold 165 shares of PSA at 165.4 per share worth 27284.2 $
# Total quantity for PSA is -165
# Date :2017-02-22 | Realised Balance: 575654.4
# Sold 387 shares of PG at 74.2 per share worth 28721.6 $
# Total quantity for PG is -387
# Date :2017-02-22 | Realised Balance: 604376.0
# Sold 706 shares of AMZN at 42.8 per share worth 30203.0 $
# Total quantity for AMZN is -706
# Date :2017-02-22 | Realised Balance: 634579.0
# Sold 363 shares of PEP at 87.4 per share worth 31721.6 $
# Total quantity for PEP is -363
# Date :2017-02-22 | Realised Balance: 666300.6
# Bought 906 shares of COP at 36.7 per share worth 33280.7 $
# Total quantity for COP is 906
# Date :2017-03-09 | Realised Balance: 633020.0
# Bought 506 shares of WFC at 45.0 per share worth 22746.7 $
# Total quantity for WFC is 0
# Date :2017-03-24 | Realised Balance: 610273.3
# Bought 678 shares of WFC at 45.0 per share worth 30478.7 $
# Total quantity for WFC is 678
# Date :2017-03-24 | Realised Balance: 579794.6
# Bought 409 shares of JPM at 70.8 per share worth 28972.5 $
# Total quantity for JPM is 409
# Date :2017-03-24 | Realised Balance: 550822.1
# Bought 237 shares of IBM at 115.7 per share worth 27428.3 $
# Total quantity for IBM is 237
# Date :2017-04-17 | Realised Balance: 523393.8
# Sold 615 shares of O at 42.5 per share worth 26142.9 $
# Total quantity for O is -615
# Date :2017-04-18 | Realised Balance: 549536.8
# Sold 186 shares of AVB at 147.4 per share worth 27424.9 $
# Total quantity for AVB is -186
# Date :2017-04-18 | Realised Balance: 576961.6
# Sold 845 shares of KO at 34.1 per share worth 28823.7 $
# Total quantity for KO is -845
# Date :2017-04-19 | Realised Balance: 605785.3
# Sold 884 shares of AAPL at 34.2 per share worth 30262.6 $
# Total quantity for AAPL is -884
# Date :2017-05-03 | Realised Balance: 636048.0
# Bought 615 shares of O at 38.9 per share worth 23936.6 $
# Total quantity for O is 0
# Date :2017-05-05 | Realised Balance: 612111.4
# Bought 786 shares of O at 38.9 per share worth 30592.1 $
# Total quantity for O is 786
# Date :2017-05-05 | Realised Balance: 581519.2
# Bought 510 shares of XOM at 57.0 per share worth 29066.6 $
# Total quantity for XOM is 510
# Date :2017-06-05 | Realised Balance: 552452.6
# Bought 387 shares of PG at 71.3 per share worth 27583.7 $
# Total quantity for PG is 0
# Date :2017-06-30 | Realised Balance: 524868.9
# Bought 368 shares of PG at 71.3 per share worth 26229.5 $
# Total quantity for PG is 368
# Date :2017-06-30 | Realised Balance: 498639.5
# Bought 186 shares of AVB at 147.2 per share worth 27383.7 $
# Total quantity for AVB is 0
# Date :2017-07-12 | Realised Balance: 471255.7
# Bought 160 shares of AVB at 147.2 per share worth 23555.9 $
# Total quantity for AVB is 160
# Date :2017-07-12 | Realised Balance: 447699.8
# Sold 314 shares of EOG at 72.4 per share worth 22737.4 $
# Total quantity for EOG is 0
# Date :2017-07-20 | Realised Balance: 470437.2
# Sold 324 shares of EOG at 72.4 per share worth 23461.5 $
# Total quantity for EOG is -324
# Date :2017-07-20 | Realised Balance: 493898.7
# Sold 368 shares of PG at 74.4 per share worth 27363.4 $
# Total quantity for PG is 0
# Date :2017-07-28 | Realised Balance: 521262.2
# Sold 350 shares of PG at 74.4 per share worth 26025.0 $
# Total quantity for PG is -350
# Date :2017-07-28 | Realised Balance: 547287.2
# Bought 324 shares of EOG at 65.0 per share worth 21064.3 $
# Total quantity for EOG is 0
# Date :2017-08-18 | Realised Balance: 526222.9
# Bought 404 shares of EOG at 65.0 per share worth 26265.3 $
# Total quantity for EOG is 404
# Date :2017-08-18 | Realised Balance: 499957.6
# Sold 309 shares of CVX at 82.1 per share worth 25380.4 $
# Total quantity for CVX is 0
# Date :2017-09-08 | Realised Balance: 525338.0
# Sold 319 shares of CVX at 82.1 per share worth 26201.7 $
# Total quantity for CVX is -319
# Date :2017-09-08 | Realised Balance: 551539.7
# Sold 786 shares of O at 41.1 per share worth 32314.4 $
# Total quantity for O is 0
# Date :2017-09-12 | Realised Balance: 583854.1
# Sold 710 shares of O at 41.1 per share worth 29189.9 $
# Total quantity for O is -710
# Date :2017-09-12 | Realised Balance: 613044.0
# Bought 165 shares of PSA at 155.6 per share worth 25666.2 $
# Total quantity for PSA is 0
# Date :2017-10-27 | Realised Balance: 587377.8
# Bought 188 shares of PSA at 155.6 per share worth 29243.9 $
# Total quantity for PSA is 188
# Date :2017-10-27 | Realised Balance: 558133.9
# Bought 545 shares of WELL at 51.2 per share worth 27888.9 $
# Total quantity for WELL is 545
# Date :2017-10-27 | Realised Balance: 530245.0
# Sold 404 shares of EOG at 80.8 per share worth 32644.0 $
# Total quantity for EOG is 0
# Date :2017-11-08 | Realised Balance: 562889.0
# Sold 348 shares of EOG at 80.8 per share worth 28119.1 $
# Total quantity for EOG is -348
# Date :2017-11-08 | Realised Balance: 591008.1
# Sold 409 shares of JPM at 87.3 per share worth 35692.7 $
# Total quantity for JPM is 0
# Date :2017-12-05 | Realised Balance: 626700.8
# Sold 359 shares of JPM at 87.3 per share worth 31329.3 $
# Total quantity for JPM is -359
# Date :2017-12-05 | Realised Balance: 658030.1
# Bought 710 shares of O at 38.7 per share worth 27475.7 $
# Total quantity for O is 0
# Date :2017-12-07 | Realised Balance: 630554.4
# Bought 814 shares of O at 38.7 per share worth 31500.3 $
# Total quantity for O is 814
# Date :2017-12-07 | Realised Balance: 599054.1
# Sold 906 shares of COP at 44.7 per share worth 40486.2 $
# Total quantity for COP is 0
# Date :2017-12-27 | Realised Balance: 639540.4
# Sold 715 shares of COP at 44.7 per share worth 31951.0 $
# Total quantity for COP is -715
# Date :2017-12-27 | Realised Balance: 671491.4
# Sold 678 shares of WFC at 51.0 per share worth 34594.3 $
# Total quantity for WFC is 0
# Date :2018-01-08 | Realised Balance: 706085.7
# Sold 691 shares of WFC at 51.0 per share worth 35257.6 $
# Total quantity for WFC is -691
# Date :2018-01-08 | Realised Balance: 741343.3
# Sold 443 shares of MSFT at 83.6 per share worth 37055.0 $
# Total quantity for MSFT is -443
# Date :2018-01-18 | Realised Balance: 778398.3
# Bought 884 shares of AAPL at 38.4 per share worth 33941.3 $
# Total quantity for AAPL is 0
# Date :2018-02-06 | Realised Balance: 744457.0
# Bought 969 shares of AAPL at 38.4 per share worth 37204.9 $
# Total quantity for AAPL is 969
# Date :2018-02-06 | Realised Balance: 707252.1
# Bought 350 shares of PG at 68.5 per share worth 23968.6 $
# Total quantity for PG is 0
# Date :2018-02-07 | Realised Balance: 683283.5
# Bought 498 shares of PG at 68.5 per share worth 34103.9 $
# Total quantity for PG is 498
# Date :2018-02-07 | Realised Balance: 649179.6
# Bought 691 shares of WFC at 46.4 per share worth 32089.2 $
# Total quantity for WFC is 0
# Date :2018-02-09 | Realised Balance: 617090.4
# Bought 664 shares of WFC at 46.4 per share worth 30835.3 $
# Total quantity for WFC is 664
# Date :2018-02-09 | Realised Balance: 586255.1
# Bought 348 shares of AXP at 83.7 per share worth 29123.6 $
# Total quantity for AXP is 0
# Date :2018-02-09 | Realised Balance: 557131.5
# Bought 332 shares of AXP at 83.7 per share worth 27784.6 $
# Total quantity for AXP is 332
# Date :2018-02-09 | Realised Balance: 529346.8
# Bought 363 shares of PEP at 91.3 per share worth 33136.1 $
# Total quantity for PEP is 0
# Date :2018-02-09 | Realised Balance: 496210.7
# Bought 271 shares of PEP at 91.3 per share worth 24738.0 $
# Total quantity for PEP is 271
# Date :2018-02-09 | Realised Balance: 471472.7
# Bought 173 shares of COST at 162.8 per share worth 28158.2 $
# Total quantity for COST is 0
# Date :2018-02-09 | Realised Balance: 443314.6
# Bought 136 shares of COST at 162.8 per share worth 22135.9 $
# Total quantity for COST is 136
# Date :2018-02-09 | Realised Balance: 421178.7
# Bought 348 shares of EOG at 80.0 per share worth 27838.8 $
# Total quantity for EOG is 0
# Date :2018-02-12 | Realised Balance: 393339.9
# Bought 245 shares of EOG at 80.0 per share worth 19599.1 $
# Total quantity for EOG is 245
# Date :2018-02-12 | Realised Balance: 373740.8
# Bought 715 shares of COP at 43.2 per share worth 30863.3 $
# Total quantity for COP is 0
# Date :2018-02-12 | Realised Balance: 342877.5
# Bought 397 shares of COP at 43.2 per share worth 17136.7 $
# Total quantity for COP is 397
# Date :2018-02-12 | Realised Balance: 325740.8
# Bought 845 shares of KO at 34.8 per share worth 29420.9 $
# Total quantity for KO is 0
# Date :2018-03-26 | Realised Balance: 296319.9
# Bought 425 shares of KO at 34.8 per share worth 14797.5 $
# Total quantity for KO is 425
# Date :2018-03-26 | Realised Balance: 281522.5
# Bought 359 shares of JPM at 89.6 per share worth 32171.7 $
# Total quantity for JPM is 0
# Date :2018-03-28 | Realised Balance: 249350.8
# Bought 139 shares of JPM at 89.6 per share worth 12456.5 $
# Total quantity for JPM is 139
# Date :2018-03-28 | Realised Balance: 236894.3
# Sold 188 shares of PSA at 161.0 per share worth 30273.1 $
# Total quantity for PSA is 0
# Date :2018-05-08 | Realised Balance: 267167.4
# Sold 82 shares of PSA at 161.0 per share worth 13204.2 $
# Total quantity for PSA is -82
# Date :2018-05-08 | Realised Balance: 280371.6
# Sold 664 shares of WFC at 45.4 per share worth 30137.6 $
# Total quantity for WFC is 0
# Date :2018-05-11 | Realised Balance: 310509.2
# Sold 342 shares of WFC at 45.4 per share worth 15522.7 $
# Total quantity for WFC is -342
# Date :2018-05-11 | Realised Balance: 326031.9
# Sold 814 shares of O at 38.2 per share worth 31086.5 $
# Total quantity for O is 0
# Date :2018-05-11 | Realised Balance: 357118.4
# Sold 467 shares of O at 38.2 per share worth 17834.6 $
# Total quantity for O is -467
# Date :2018-05-11 | Realised Balance: 374953.0
# Sold 139 shares of JPM at 95.0 per share worth 13198.9 $
# Total quantity for JPM is 0
# Date :2018-05-11 | Realised Balance: 388152.0
# Sold 204 shares of JPM at 95.0 per share worth 19371.1 $
# Total quantity for JPM is -204
# Date :2018-05-11 | Realised Balance: 407523.0
# Sold 397 shares of COP at 56.7 per share worth 22504.0 $
# Total quantity for COP is 0
# Date :2018-05-16 | Realised Balance: 430027.0
# Sold 379 shares of COP at 56.7 per share worth 21483.6 $
# Total quantity for COP is -379
# Date :2018-05-16 | Realised Balance: 451510.6
# Sold 545 shares of WELL at 45.9 per share worth 25023.1 $
# Total quantity for WELL is 0
# Date :2018-05-31 | Realised Balance: 476533.8
# Sold 518 shares of WELL at 45.9 per share worth 23783.5 $
# Total quantity for WELL is -518
# Date :2018-05-31 | Realised Balance: 500317.2
# Sold 969 shares of AAPL at 45.9 per share worth 44500.3 $
# Total quantity for AAPL is 0
# Date :2018-06-07 | Realised Balance: 544817.5
# Sold 593 shares of AAPL at 45.9 per share worth 27232.9 $
# Total quantity for AAPL is -593
# Date :2018-06-07 | Realised Balance: 572050.4
# Sold 425 shares of KO at 36.0 per share worth 15313.9 $
# Total quantity for KO is 0
# Date :2018-06-13 | Realised Balance: 587364.3
# Sold 815 shares of KO at 36.0 per share worth 29366.7 $
# Total quantity for KO is -815
# Date :2018-06-13 | Realised Balance: 616731.1
# Sold 136 shares of COST at 184.9 per share worth 25140.9 $
# Total quantity for COST is 0
# Date :2018-06-13 | Realised Balance: 641872.0
# Sold 173 shares of COST at 184.9 per share worth 31980.7 $
# Total quantity for COST is -173
# Date :2018-06-13 | Realised Balance: 673852.6
# Sold 271 shares of PEP at 88.0 per share worth 23838.0 $
# Total quantity for PEP is 0
# Date :2018-06-18 | Realised Balance: 697690.6
# Sold 396 shares of PEP at 88.0 per share worth 34833.4 $
# Total quantity for PEP is -396
# Date :2018-06-18 | Realised Balance: 732524.0
# Bought 106 shares of GS at 193.2 per share worth 20482.0 $
# Total quantity for GS is 0
# Date :2018-06-28 | Realised Balance: 712042.0
# Bought 184 shares of GS at 193.2 per share worth 35553.6 $
# Total quantity for GS is 184
# Date :2018-06-28 | Realised Balance: 676488.4
# Bought 204 shares of JPM at 87.5 per share worth 17851.8 $
# Total quantity for JPM is 0
# Date :2018-06-28 | Realised Balance: 658636.6
# Bought 376 shares of JPM at 87.5 per share worth 32903.4 $
# Total quantity for JPM is 376
# Date :2018-06-28 | Realised Balance: 625733.2
# Sold 160 shares of AVB at 139.0 per share worth 22234.3 $
# Total quantity for AVB is 0
# Date :2018-07-02 | Realised Balance: 647967.5
# Sold 233 shares of AVB at 139.0 per share worth 32378.6 $
# Total quantity for AVB is -233
# Date :2018-07-02 | Realised Balance: 680346.1
# Sold 498 shares of PG at 66.9 per share worth 33292.3 $
# Total quantity for PG is 0
# Date :2018-07-11 | Realised Balance: 713638.4
# Sold 533 shares of PG at 66.9 per share worth 35632.1 $
# Total quantity for PG is -533
# Date :2018-07-11 | Realised Balance: 749270.5
# Bought 319 shares of CVX at 90.7 per share worth 28925.2 $
# Total quantity for CVX is 0
# Date :2018-08-17 | Realised Balance: 720345.3
# Bought 397 shares of CVX at 90.7 per share worth 35997.9 $
# Total quantity for CVX is 397
# Date :2018-08-17 | Realised Balance: 684347.4
# Sold 184 shares of GS at 209.6 per share worth 38569.2 $
# Total quantity for GS is 0
# Date :2018-08-28 | Realised Balance: 722916.6
# Sold 172 shares of GS at 209.6 per share worth 36053.8 $
# Total quantity for GS is -172
# Date :2018-08-28 | Realised Balance: 758970.5
# Sold 332 shares of AXP at 98.6 per share worth 32737.3 $
# Total quantity for AXP is 0
# Date :2018-08-28 | Realised Balance: 791707.8
# Sold 401 shares of AXP at 98.6 per share worth 39541.1 $
# Total quantity for AXP is -401
# Date :2018-08-28 | Realised Balance: 831248.9
# Bought 82 shares of PSA at 160.2 per share worth 13133.4 $
# Total quantity for PSA is 0
# Date :2018-09-20 | Realised Balance: 818115.5
# Bought 255 shares of PSA at 160.2 per share worth 40841.7 $
# Total quantity for PSA is 255
# Date :2018-09-20 | Realised Balance: 777273.8
# Sold 376 shares of JPM at 98.8 per share worth 37155.5 $
# Total quantity for JPM is 0
# Date :2018-09-21 | Realised Balance: 814429.3
# Sold 412 shares of JPM at 98.8 per share worth 40713.0 $
# Total quantity for JPM is -412
# Date :2018-09-21 | Realised Balance: 855142.3
# Sold 397 shares of CVX at 93.9 per share worth 37266.0 $
# Total quantity for CVX is 0
# Date :2018-09-26 | Realised Balance: 892408.4
# Sold 475 shares of CVX at 93.9 per share worth 44587.8 $
# Total quantity for CVX is -475
# Date :2018-09-26 | Realised Balance: 936996.2
# Bought 706 shares of AMZN at 89.4 per share worth 63137.9 $
# Total quantity for AMZN is 0
# Date :2018-10-12 | Realised Balance: 873858.3
# Bought 488 shares of AMZN at 89.4 per share worth 43642.1 $
# Total quantity for AMZN is 488
# Date :2018-10-12 | Realised Balance: 830216.2
# Bought 533 shares of PG at 68.3 per share worth 36396.1 $
# Total quantity for PG is 0
# Date :2018-10-15 | Realised Balance: 793820.1
# Bought 581 shares of PG at 68.3 per share worth 39673.8 $
# Total quantity for PG is 581
# Date :2018-10-15 | Realised Balance: 754146.3
# Bought 233 shares of AVB at 142.0 per share worth 33088.1 $
# Total quantity for AVB is 0
# Date :2018-10-15 | Realised Balance: 721058.2
# Bought 253 shares of AVB at 142.0 per share worth 35928.3 $
# Total quantity for AVB is 253
# Date :2018-10-15 | Realised Balance: 685129.9
# Bought 412 shares of JPM at 91.7 per share worth 37787.1 $
# Total quantity for JPM is 0
# Date :2018-10-16 | Realised Balance: 647342.8
# Bought 352 shares of JPM at 91.7 per share worth 32284.2 $
# Total quantity for JPM is 352
# Date :2018-10-16 | Realised Balance: 615058.6
# Bought 172 shares of GS at 185.7 per share worth 31940.5 $
# Total quantity for GS is 0
# Date :2018-10-25 | Realised Balance: 583118.1
# Bought 157 shares of GS at 185.7 per share worth 29155.0 $
# Total quantity for GS is 157
# Date :2018-10-25 | Realised Balance: 553963.0
# Bought 475 shares of CVX at 85.9 per share worth 40796.3 $
# Total quantity for CVX is 0
# Date :2018-10-25 | Realised Balance: 513166.7
# Bought 298 shares of CVX at 85.9 per share worth 25594.3 $
# Total quantity for CVX is 298
# Date :2018-10-25 | Realised Balance: 487572.4
# Bought 379 shares of COP at 55.7 per share worth 21095.1 $
# Total quantity for COP is 0
# Date :2018-10-25 | Realised Balance: 466477.3
# Bought 419 shares of COP at 55.7 per share worth 23321.5 $
# Total quantity for COP is 419
# Date :2018-10-25 | Realised Balance: 443155.8
# Bought 593 shares of AAPL at 42.3 per share worth 25059.3 $
# Total quantity for AAPL is 0
# Date :2018-11-21 | Realised Balance: 418096.5
# Bought 494 shares of AAPL at 42.3 per share worth 20875.7 $
# Total quantity for AAPL is 494
# Date :2018-11-21 | Realised Balance: 397220.8
# Sold 255 shares of PSA at 167.3 per share worth 42658.5 $
# Total quantity for PSA is 0
# Date :2018-12-07 | Realised Balance: 439879.4
# Sold 131 shares of PSA at 167.3 per share worth 21914.8 $
# Total quantity for PSA is -131
# Date :2018-12-07 | Realised Balance: 461794.1
# Bought 815 shares of KO at 39.3 per share worth 31998.0 $
# Total quantity for KO is 0
# Date :2018-12-26 | Realised Balance: 429796.1
# Bought 547 shares of KO at 39.3 per share worth 21476.0 $
# Total quantity for KO is 547
# Date :2018-12-26 | Realised Balance: 408320.1
# Bought 396 shares of PEP at 91.9 per share worth 36391.4 $
# Total quantity for PEP is 0
# Date :2018-12-26 | Realised Balance: 371928.7
# Bought 202 shares of PEP at 91.9 per share worth 18563.3 $
# Total quantity for PEP is 202
# Date :2018-12-26 | Realised Balance: 353365.5
# Sold 157 shares of GS at 172.2 per share worth 27039.4 $
# Total quantity for GS is 0
# Date :2019-01-22 | Realised Balance: 380404.9
# Sold 110 shares of GS at 172.2 per share worth 18944.8 $
# Total quantity for GS is -110
# Date :2019-01-22 | Realised Balance: 399349.7
# Sold 581 shares of PG at 84.4 per share worth 49055.6 $
# Total quantity for PG is 0
# Date :2019-02-05 | Realised Balance: 448405.3
# Sold 265 shares of PG at 84.4 per share worth 22374.7 $
# Total quantity for PG is -265
# Date :2019-02-05 | Realised Balance: 470780.0
# Sold 510 shares of XOM at 56.8 per share worth 28976.3 $
# Total quantity for XOM is 0
# Date :2019-02-06 | Realised Balance: 499756.3
# Sold 439 shares of XOM at 56.8 per share worth 24942.3 $
# Total quantity for XOM is -439
# Date :2019-02-06 | Realised Balance: 524698.6
# Sold 298 shares of CVX at 92.4 per share worth 27535.3 $
# Total quantity for CVX is 0
# Date :2019-02-06 | Realised Balance: 552233.9
# Sold 298 shares of CVX at 92.4 per share worth 27535.3 $
# Total quantity for CVX is -298
# Date :2019-02-06 | Realised Balance: 579769.2
# Sold 494 shares of AAPL at 40.9 per share worth 20186.1 $
# Total quantity for AAPL is 0
# Date :2019-02-07 | Realised Balance: 599955.3
# Sold 734 shares of AAPL at 40.9 per share worth 29993.0 $
# Total quantity for AAPL is -734
# Date :2019-02-07 | Realised Balance: 629948.3
# Sold 253 shares of AVB at 164.8 per share worth 41699.0 $
# Total quantity for AVB is 0
# Date :2019-03-15 | Realised Balance: 671647.4
# Sold 203 shares of AVB at 164.8 per share worth 33458.1 $
# Total quantity for AVB is -203
# Date :2019-03-15 | Realised Balance: 705105.5
# Sold 352 shares of JPM at 90.9 per share worth 32001.0 $
# Total quantity for JPM is 0
# Date :2019-03-19 | Realised Balance: 737106.5
# Sold 405 shares of JPM at 90.9 per share worth 36819.3 $
# Total quantity for JPM is -405
# Date :2019-03-19 | Realised Balance: 773925.8
# Sold 488 shares of AMZN at 88.2 per share worth 43060.4 $
# Total quantity for AMZN is 0
# Date :2019-03-22 | Realised Balance: 816986.2
# Sold 462 shares of AMZN at 88.2 per share worth 40766.2 $
# Total quantity for AMZN is -462
# Date :2019-03-22 | Realised Balance: 857752.4
# Bought 405 shares of JPM at 85.1 per share worth 34447.4 $
# Total quantity for JPM is 0
# Date :2019-03-26 | Realised Balance: 823305.0
# Bought 483 shares of JPM at 85.1 per share worth 41081.8 $
# Total quantity for JPM is 483
# Date :2019-03-26 | Realised Balance: 782223.2
# Bought 518 shares of WELL at 60.6 per share worth 31380.4 $
# Total quantity for WELL is 0
# Date :2019-04-18 | Realised Balance: 750842.8
# Bought 619 shares of WELL at 60.6 per share worth 37498.9 $
# Total quantity for WELL is 619
# Date :2019-04-18 | Realised Balance: 713343.9
# Sold 245 shares of EOG at 83.5 per share worth 20445.4 $
# Total quantity for EOG is 0
# Date :2019-04-23 | Realised Balance: 733789.3
# Sold 439 shares of EOG at 83.5 per share worth 36634.8 $
# Total quantity for EOG is -439
# Date :2019-04-23 | Realised Balance: 770424.1
# Sold 547 shares of KO at 41.0 per share worth 22425.0 $
# Total quantity for KO is 0
# Date :2019-05-01 | Realised Balance: 792849.1
# Sold 966 shares of KO at 41.0 per share worth 39602.4 $
# Total quantity for KO is -966
# Date :2019-05-01 | Realised Balance: 832451.5
# Bought 110 shares of GS at 161.0 per share worth 17706.5 $
# Total quantity for GS is 0
# Date :2019-06-03 | Realised Balance: 814744.9
# Bought 253 shares of GS at 161.0 per share worth 40725.0 $
# Total quantity for GS is 253
# Date :2019-06-03 | Realised Balance: 774020.0
# Bought 342 shares of WFC at 38.4 per share worth 13130.7 $
# Total quantity for WFC is 0
# Date :2019-06-03 | Realised Balance: 760889.3
# Bought 990 shares of WFC at 38.4 per share worth 38009.9 $
# Total quantity for WFC is 990
# Date :2019-06-03 | Realised Balance: 722879.4
# Bought 439 shares of XOM at 55.5 per share worth 24362.7 $
# Total quantity for XOM is 0
# Date :2019-06-03 | Realised Balance: 698516.6
# Bought 629 shares of XOM at 55.5 per share worth 34906.9 $
# Total quantity for XOM is 629
# Date :2019-06-03 | Realised Balance: 663609.7
# Bought 439 shares of EOG at 64.9 per share worth 28507.1 $
# Total quantity for EOG is 0
# Date :2019-06-03 | Realised Balance: 635102.6
# Bought 489 shares of EOG at 64.9 per share worth 31753.9 $
# Total quantity for EOG is 489
# Date :2019-06-03 | Realised Balance: 603348.7
# Sold 483 shares of JPM at 97.5 per share worth 47092.3 $
# Total quantity for JPM is 0
# Date :2019-07-08 | Realised Balance: 650440.9
# Sold 333 shares of JPM at 97.5 per share worth 32467.3 $
# Total quantity for JPM is -333
# Date :2019-07-08 | Realised Balance: 682908.3
# Sold 619 shares of WELL at 73.6 per share worth 45562.2 $
# Total quantity for WELL is 0
# Date :2019-08-12 | Realised Balance: 728470.5
# Sold 494 shares of WELL at 73.6 per share worth 36361.4 $
# Total quantity for WELL is -494
# Date :2019-08-12 | Realised Balance: 764831.9
# Bought 333 shares of JPM at 90.9 per share worth 30261.0 $
# Total quantity for JPM is 0
# Date :2019-08-15 | Realised Balance: 734570.9
# Bought 404 shares of JPM at 90.9 per share worth 36713.1 $
# Total quantity for JPM is 404
# Date :2019-08-15 | Realised Balance: 697857.8
# Sold 404 shares of JPM at 102.9 per share worth 41584.9 $
# Total quantity for JPM is 0
# Date :2019-09-16 | Realised Balance: 739442.7
# Sold 359 shares of JPM at 102.9 per share worth 36952.9 $
# Total quantity for JPM is -359
# Date :2019-09-16 | Realised Balance: 776395.6
# Sold 629 shares of XOM at 57.2 per share worth 35975.2 $
# Total quantity for XOM is 0
# Date :2019-09-17 | Realised Balance: 812370.8
# Sold 710 shares of XOM at 57.2 per share worth 40608.0 $
# Total quantity for XOM is -710
# Date :2019-09-17 | Realised Balance: 852978.8
# Bought 401 shares of AXP at 107.1 per share worth 42941.9 $
# Total quantity for AXP is 0
# Date :2019-10-04 | Realised Balance: 810036.9
# Bought 378 shares of AXP at 107.1 per share worth 40478.9 $
# Total quantity for AXP is 378
# Date :2019-10-04 | Realised Balance: 769558.0
# Bought 467 shares of O at 58.7 per share worth 27415.1 $
# Total quantity for O is 0
# Date :2019-11-11 | Realised Balance: 742142.9
# Bought 632 shares of O at 58.7 per share worth 37101.3 $
# Total quantity for O is 632
# Date :2019-11-11 | Realised Balance: 705041.6
# Bought 494 shares of WELL at 70.2 per share worth 34688.3 $
# Total quantity for WELL is 0
# Date :2019-11-11 | Realised Balance: 670353.2
# Bought 477 shares of WELL at 70.2 per share worth 33494.6 $
# Total quantity for WELL is 477
# Date :2019-11-11 | Realised Balance: 636858.7
# Sold 378 shares of AXP at 115.8 per share worth 43758.7 $
# Total quantity for AXP is 0
# Date :2019-12-16 | Realised Balance: 680617.3
# Sold 293 shares of AXP at 115.8 per share worth 33918.8 $
# Total quantity for AXP is -293
# Date :2019-12-16 | Realised Balance: 714536.1
# Bought 203 shares of AVB at 177.3 per share worth 35999.2 $
# Total quantity for AVB is 0
# Date :2019-12-16 | Realised Balance: 678536.9
# Bought 191 shares of AVB at 177.3 per share worth 33871.2 $
# Total quantity for AVB is 191
# Date :2019-12-16 | Realised Balance: 644665.8
# Closed open trades for 443 shares of MSFT at 151.0 per share worth 66908.2 $
# Closed open trades for 734 shares of AAPL at 70.7 per share worth 51918.5 $
# Closed open trades for 253 shares of GS at 204.3 per share worth 51697.3 $
# Closed open trades for 990 shares of WFC at 47.2 per share worth 46720.3 $
# Closed open trades for 710 shares of XOM at 55.0 per share worth 39025.1 $
# Closed open trades for 298 shares of CVX at 96.9 per share worth 28887.8 $
# Closed open trades for 131 shares of PSA at 172.5 per share worth 22596.7 $
# Closed open trades for 632 shares of O at 56.3 per share worth 35601.3 $
# Closed open trades for 265 shares of PG at 110.0 per share worth 29154.7 $
# Closed open trades for 966 shares of KO at 47.7 per share worth 46072.0 $
# Closed open trades for 462 shares of AMZN at 92.3 per share worth 42663.2 $
# Closed open trades for 237 shares of IBM at 101.4 per share worth 24035.0 $
# Closed open trades for 293 shares of AXP at 116.3 per share worth 34088.8 $
# Closed open trades for 359 shares of JPM at 120.7 per share worth 43335.2 $
# Closed open trades for 489 shares of EOG at 65.0 per share worth 31774.4 $
# Closed open trades for 419 shares of COP at 54.1 per share worth 22647.4 $
# Closed open trades for 191 shares of AVB at 177.1 per share worth 33834.3 $
# Closed open trades for 477 shares of WELL at 69.2 per share worth 32993.6 $
# Closed open trades for 202 shares of PEP at 119.5 per share worth 24139.1 $
# Closed open trades for 173 shares of COST at 271.2 per share worth 46925.0 $
# Closed open trades for 0 shares of XLK at 87.5 per share worth 0.0 $
# Closed open trades for 0 shares of XLF at 27.9 per share worth 0.0 $
# Closed open trades for 0 shares of XLE at 48.3 per share worth 0.0 $
# Closed open trades for 0 shares of IYR at 81.5 per share worth 0.0 $
# Closed open trades for 0 shares of XLP at 55.5 per share worth 0.0 $
# Closed open trades for 0 shares of XLY at 120.2 per share worth 0.0 $
# ==================================================
# Performance Metrics
# The total capital at end of strategy: 496533.3
# The annual regular returns: -0.24 %
# The annual regular std deviation: 7.01 %
# The annual Sharpe Ratio: -0.03
# The returns on investment from 2017-01-01 to 2019-12-31 by this strategy is -0.7 %
# The maximum drawdown: 8.53 %
# The maximum drawdown period: 241.00 days
# The annual Sortino Ratio: -0.06
# The total trades taken by the strategy: 210
# ==================================================
